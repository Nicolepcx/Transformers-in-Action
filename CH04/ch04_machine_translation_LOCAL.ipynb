# %% [markdown]
# # About this notebook

# %% [markdown]
# In this notebook, we will explore Neural Machine Translation (NMT) using the Facebook `mbart-large-50-many-to-many-mmt` model and the WMT16 dataset from Hugging Face. Our primary focus will be on the English-German (en-de) translation task, and we will evaluate the performance of the model using two popular metrics: BLEU and METEOR.
#
# __Key points:__
#
# - Facebook mbart-large-50-many-to-many-mmt model: A pre-trained multilingual model designed for machine translation tasks, supporting translations between 50 languages.
# - WMT16 dataset from Hugging Face: A benchmark dataset for machine translation, including parallel corpora for various language pairs.
# - English-German (en-de) translation task: The primary focus of this notebook, using the WMT16 dataset's English-German language pair.
# - Evaluation metrics:
#   - BLEU (Bilingual Evaluation Understudy): A popular metric for machine translation that measures the similarity between the model's output and the reference translation using n-gram precision.
#   - METEOR (Metric for Evaluation of Translation with Explicit Ordering): Another metric for machine translation that considers both the precision and recall of the generated translation, also accounting for synonymy and word order differences.
#
# By the end of this notebook, you will gain hands-on experience in training and evaluating an NMT model using the Facebook mbart-large-50-many-to-many-mmt model and the WMT16 dataset, as well as interpreting the results using the BLEU and METEOR metrics.

# %% [markdown]
# # Imports

# %%
# Load setup.py file
# %load ../utils/setup.py
# %run ../utils/setup.py

# Load utils.py file
# %load ../utils/utils.py
# %run ../utils/utils.py

# %%
useGPU()
# Out:
# Have fun with this chapter!🥳

# %% [markdown]
# # Allocate enough RAM

# %% [markdown]
# Let us try to get a __GPU__ with at least __15GB RAM__ for our notebook.

# %%
# crash colab to get more RAM -> uncomment to use
#!kill -9 -1

# %% [markdown]
# We can execute the following command `!free -h`  to see if we have enough RAM and `!nvidia-smi` to get more info about our GPU type we got assigned.
# If the allocated GPU is too small, the above cell can be used to run the command to crash the notebook hoping to get a better GPU after the crash, since the GPU is randomly allocated.

# %%
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:           83Gi       1.2Gi        77Gi       3.0Mi       4.3Gi        81Gi
# Swap:            0B          0B          0B

# %%
# !nvidia-smi
# Out:
# Wed Apr 12 16:42:39 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    46W / 400W |      3MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch

if torch.cuda.is_available():
    gpu_device = torch.device('cuda')
    gpu_info = torch.cuda.get_device_properties(gpu_device)
    gpu_memory = gpu_info.total_memory / 1e9  # Convert bytes to gigabytes
    print(f"GPU: {gpu_info.name}, Total Memory: {gpu_memory:.2f} GB")
else:
    print("No GPU detected.")
# Out:
# GPU: NVIDIA A100-SXM4-40GB, Total Memory: 42.48 GB

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb=32"

# %%
from transformers import (
    MarianMTModel, 
    MarianTokenizer, 
    MBartForConditionalGeneration, 
    MBart50TokenizerFast,
    pipeline,
    set_seed
)

import evaluate
from datasets import load_dataset
import sacrebleu
import logging
import pandas as pd
import torch
from textwrap import TextWrapper
import warnings 
warnings.filterwarnings('ignore')
set_seed(42)

# %% [markdown]
# ## Set number of examples for translations

# %%
# Set number of examples
num_examples = 100

# %% [markdown]
# ## Load dataset

# %% [markdown]
# The WMT16 dataset is part of the Workshop on Machine Translation (WMT) series, specifically from the 2016 edition. WMT is an annual conference that focuses on research in the field of machine translation and aims to evaluate and compare the performance of different machine translation systems.
#
# The WMT16 dataset, available through the Hugging Face Datasets library, includes parallel corpora for various language pairs used in the WMT 2016 shared task on machine translation. The dataset contains both news commentaries and Europarl data, as well as common test sets for multiple language pairs.
#
# Some of the language pairs included in the WMT16 dataset are:
#
# - English-German (en-de)
# - English-Russian (en-ru)
# - English-Czech (en-cs)
# - English-Romanian (en-ro)
# - English-Turkish (en-tr)
#
# [Link to dataset on Hugging Face](https://huggingface.co/datasets/wmt16)

# %%
# Load the WMT16 English-German dataset
dataset = load_dataset("wmt16", "de-en", split=f"test[:{num_examples}]")
# Out:
# Downloading builder script:   0%|          | 0.00/2.81k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/18.6k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/9.89k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/41.4k [00:00<?, ?B/s]
# Downloading and preparing dataset wmt16/de-en to /root/.cache/huggingface/datasets/wmt16/de-en/1.0.0/746749a11d25c02058042da7502d973ff410e73457f3d305fc1177dc0e8c4227...
# Downloading data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/658M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/919M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/75.2M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/38.7M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split:   0%|          | 0/4548885 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2169 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2999 [00:00<?, ? examples/s]
# Dataset wmt16 downloaded and prepared to /root/.cache/huggingface/datasets/wmt16/de-en/1.0.0/746749a11d25c02058042da7502d973ff410e73457f3d305fc1177dc0e8c4227. Subsequent calls will reuse this data.

# %%
dataset
# Out:
# Dataset({
#     features: ['translation'],
#     num_rows: 100
# })

# %% [markdown]
# ## Initialize the models

# %%
# Initialize the mBART-50 model and tokenizer
mbart_model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
mbart_tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")

# Initialize the MarianMT model and tokenizer
opus_model_name = "Helsinki-NLP/opus-mt-en-de"
opus_tokenizer = MarianTokenizer.from_pretrained(opus_model_name)
opus_model = MarianMTModel.from_pretrained(opus_model_name)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/529 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/768k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/797k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/298M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]

# %%
# Load the Google BLEU metric
bleu = evaluate.load("google_bleu")
# Out:
# Downloading builder script:   0%|          | 0.00/8.64k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]

# %% [markdown]
# ## Loop over translations

# %%
translations = {'mBART-50': [], 'OPUS-MT': []}

# Loop over the chosen examples in the dataset and translate them using both models
for i in range(num_examples):
    # Translate using mBART-50
    input_text = dataset[i]["translation"]["en"]
    target_text = dataset[i]["translation"]["de"]
    encoded = mbart_tokenizer(input_text, return_tensors="pt")
    generated_tokens = mbart_model.generate(**encoded, forced_bos_token_id=mbart_tokenizer.lang_code_to_id["de_DE"])
    output_text_mbart = mbart_tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
    translations['mBART-50'].append(output_text_mbart)
    
    # Translate using OPUS-MT
    input_text = dataset[i]["translation"]["en"]
    target_text = dataset[i]["translation"]["de"]
    encoded = opus_tokenizer(input_text, return_tensors="pt")
    generated_tokens = opus_model.generate(**encoded)
    output_text_opus = opus_tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
    translations['OPUS-MT'].append(output_text_opus)

    print(f"\033[1m\nExample {i + 1}\033[0m")
    print(f"\033[1mInput:\033[0m {input_text}")
    print(f"\033[1mGround truth:\033[0m {target_text}")
    print("==="*23)
    print("\033[1mModel: OPUS-MT\033[0m")
    print(f"Output: {output_text_opus}")
    print("---"*23)
    print("\033[1mModel: mBART-50\033[0m")
    print(f"Output: {output_text_mbart}\n")
    print("###"*23)

# Set up logging for the warning messages
logging.getLogger("transformers").setLevel(logging.ERROR)
# Out:
# Example 1
# Input: Obama receives Netanyahu
# Ground truth: Obama empfängt Netanyahu
# =====================================================================
# Model: OPUS-MT
# Output: Obama erhält Netanjahu
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Obama erhält Netanyahu
#
# #####################################################################
#
# Example 2
# Input: The relationship between Obama and Netanyahu is not
# exactly friendly.
# Ground truth: Das Verhältnis zwischen Obama und Netanyahu ist
# nicht gerade freundschaftlich.
# =====================================================================
# Model: OPUS-MT
# Output: Die Beziehung zwischen Obama und Netanjahu ist nicht gerade
# freundlich.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Die Beziehung zwischen Obama und Netanjahu ist nicht gerade
# freundlich.
#
# #####################################################################
#
# Example 3
# Input: The two wanted to talk about the implementation of the
# international agreement and about Teheran's destabilising activities
# in the Middle East.
# Ground truth: Die beiden wollten über die Umsetzung der
# internationalen Vereinbarung sowie über Teherans destabilisierende
# Maßnahmen im Nahen Osten sprechen.
# =====================================================================
# Model: OPUS-MT
# Output: Beide wollten über die Umsetzung des internationalen Abkommens
# und über Teherans destabilisierende Aktivitäten im Nahen Osten
# sprechen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Die beiden wollten über die Umsetzung des internationalen
# Abkommens und über die destabilisierenden Aktivitäten Teherans im
# Nahen Osten sprechen.
#
# #####################################################################
#
# Example 4
# Input: The meeting was also planned to cover the conflict with
# the Palestinians and the disputed two state solution.
# Ground truth: Bei der Begegnung soll es aber auch um den
# Konflikt mit den Palästinensern und die diskutierte Zwei-Staaten-
# Lösung gehen.
# =====================================================================
# Model: OPUS-MT
# Output: Das Treffen sollte auch den Konflikt mit den Palästinensern
# und die umstrittene zwei staatliche Lösung abdecken.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Das Treffen sollte auch den Konflikt mit den Palästinensern
# und die umstrittene Lösung der beiden Staaten abdecken.
#
# #####################################################################
#
# Example 5
# Input: Relations between Obama and Netanyahu have been
# strained for years.
# Ground truth: Das Verhältnis zwischen Obama und Netanyahu ist
# seit Jahren gespannt.
# =====================================================================
# Model: OPUS-MT
# Output: Die Beziehungen zwischen Obama und Netanjahu sind seit Jahren
# angespannt.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Die Beziehungen zwischen Obama und Netanjahu sind seit Jahren
# angespannt.
#
# #####################################################################
#
# Example 6
# Input: Washington criticises the continuous building of
# settlements in Israel and accuses Netanyahu of a lack of initiative in
# the peace process.
# Ground truth: Washington kritisiert den andauernden
# Siedlungsbau Israels und wirft Netanyahu mangelnden Willen beim
# Friedensprozess vor.
# =====================================================================
# Model: OPUS-MT
# Output: Washington kritisiert den kontinuierlichen Bau von Siedlungen
# in Israel und wirft Netanjahu einen Mangel an Initiative im
# Friedensprozess vor.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Washington kritisiert den kontinuierlichen Aufbau von
# Siedlungen in Israel und beschuldigt Netanjahu von einem Mangel an
# Initiative im Friedensprozess.
#
# #####################################################################
#
# Example 7
# Input: The relationship between the two has further
# deteriorated because of the deal that Obama negotiated on Iran's
# atomic programme, .
# Ground truth: Durch den von Obama beworbenen Deal um das
# iranische Atomprogramm hat sich die Beziehung der beiden weiter
# verschlechtert.
# =====================================================================
# Model: OPUS-MT
# Output: Die Beziehung zwischen den beiden hat sich aufgrund des
# Abkommens, das Obama über das iranische Atomprogramm ausgehandelt hat,
# weiter verschlechtert.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Die Beziehungen zwischen den beiden haben sich aufgrund des
# Abkommens, das Obama über das Atomprogramm Irans verhandelt hat,
# weiter verschlechtert.
#
# #####################################################################
#
# Example 8
# Input: In March, at the invitation of the Republicans,
# Netanyahu made a controversial speech to the US Congress, which was
# partly seen as an affront to Obama.
# Ground truth: Im März hatte Netanyahu auf Einladung der
# Republikaner vor dem US-Kongress eine umstrittene Rede gehalten, die
# teils als Affront gegen Obama gewertet wurde.
# =====================================================================
# Model: OPUS-MT
# Output: Im März hielt Netanjahu auf Einladung der Republikaner eine
# kontroverse Rede vor dem US-Kongress, die teilweise als Affront gegen
# Obama angesehen wurde.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Im März hielt Netanyahu auf Einladung der Republikaner im US-
# Kongress eine kontroverse Rede, die zum Teil als Affront gegen Obama
# angesehen wurde.
#
# #####################################################################
#
# Example 9
# Input: The speech had not been agreed with Obama, who had
# rejected a meeting with reference to the election that was at that
# time impending in Israel.
# Ground truth: Die Rede war mit Obama nicht abgesprochen, ein
# Treffen hatte dieser mit Hinweis auf die seinerzeit bevorstehende Wahl
# in Israel abgelehnt.
# =====================================================================
# Model: OPUS-MT
# Output: Die Rede war nicht mit Obama abgestimmt worden, der ein
# Treffen mit Bezug auf die Wahlen, die damals in Israel bevorstand,
# abgelehnt hatte.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Die Rede wurde nicht mit Obama vereinbart, der eine Sitzung
# mit Bezug auf die damals in Israel bevorstehenden Wahlen abgelehnt
# hatte.
#
# #####################################################################
#
# Example 10
# Input: In 911 Call, Professor Admits to Shooting Girlfriend
# Ground truth: In einem Notruf gesteht Professor, seine
# Freundin erschossen zu haben
# =====================================================================
# Model: OPUS-MT
# Output: In 911 Call, Professor zulässt zu schießen Freundin
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: In 911-Anruf, Professor bekennt sich zu Shooting Girlfriend
#
# #####################################################################
#
# Example 11
# Input: In a 911 call, his voice only slightly shaky, college
# professor Shannon Lamb told police he had shot his girlfriend and
# officers needed to get over to their house.
# Ground truth: In einem Notruf erzählte Professor Shannon Lamb
# mit einer etwas zittrigen Stimme der Polizei, dass er seine Freundin
# erschossen habe und dass die Beamten zu seinem Haus kommen müssten.
# =====================================================================
# Model: OPUS-MT
# Output: In einem Notruf, seine Stimme nur leicht wackelig, College-
# Professor Shannon Lamb sagte der Polizei, er hätte seine Freundin
# erschossen und Offiziere müssten rüber zu ihrem Haus kommen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: In einem 911-Anruf, seine Stimme nur leicht schüttelnd, sagte
# College-Professor Shannon Lamb der Polizei, er habe seine Freundin
# erschossen und die Beamten müssen zu ihrem Haus kommen.
#
# #####################################################################
#
# Example 12
# Input: Lamb made a point to say his "sweet dog" was there
# alive and probably upset, and said the dead woman's family contacts
# could be found on her phone.
# Ground truth: Lamb war es wichtig zu betonen, dass sein "süßer
# Hund" aber noch lebe und wahrscheinlich aufgeregt sei, und er sagte,
# die Familienkontakte der toten Frau könnten auf dem Handy gefunden
# werden.
# =====================================================================
# Model: OPUS-MT
# Output: Lamm machte einen Punkt zu sagen, sein "süßer Hund" war dort
# lebendig und wahrscheinlich verärgert, und sagte, die Familienkontakte
# der toten Frau könnten auf ihrem Handy gefunden werden.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Lamb machte einen Punkt, um zu sagen, dass sein "süßer Hund"
# dort lebendig und wahrscheinlich verärgert war, und sagte, dass die
# Familienkontakte der toten Frau auf ihrem Telefon gefunden werden
# konnten.
#
# #####################################################################
#
# Example 13
# Input: Inside the home, officers found Amy Prentiss' body and
# a hand-written note scribbled on a white legal pad: "I am so very
# sorry I wish I could take it back I loved Amy and she is the only
# woman who ever loved me," read the letter authorities say was signed
# by Lamb.
# Ground truth: Innerhalb des Hauses fanden die Beamten die
# Leiche von Amy Prentiss und eine handgeschriebene Notiz, die auf einen
# weißen Block gekritzelt war: "Mir tut es so leid, ich wollte, ich
# könnte es rückgängig machen, ich liebte Amy und sie ist die einzige
# Frau, die mich jemals liebte". Dies stand nach Angaben der Behörden in
# dem Brief, und er war von Lamb unterzeichnet.
# =====================================================================
# Model: OPUS-MT
# Output: Im Inneren des Hauses fanden Beamte Amy Prentiss' Leiche und
# eine handschriftliche Notiz, die auf einem weißen Rechtsblock
# gekritzelt wurde: "Es tut mir so leid, ich wünschte, ich könnte es
# zurücknehmen, ich liebte Amy und sie ist die einzige Frau, die mich je
# geliebt hat", lesen die Behörden sagen, dass sie von Lamb
# unterzeichnet wurde.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Im Inneren des Hauses fanden Beamte Amy Prentiss Körper und
# eine handgeschriebene Notiz auf einem weißen Rechtspapier geschrieben:
# "Ich bin so sehr leid, ich wünschte, ich könnte es zurücknehmen, ich
# liebte Amy und sie ist die einzige Frau, die mich jemals liebte",
# lesen die Briefe Behörden sagen, wurde von Lamb unterzeichnet.
#
# #####################################################################
#
# Example 14
# Input: There was no indication that Lamb, who was teaching two
# online classes for Delta State University in Cleveland, Mississippi,
# had already traveled 300 miles to the school's campus, where police
# believe he shot and killed a well-liked history professor, Ethan
# Schmidt, in the doorway to his office.
# Ground truth: Es gab keinen Hinweis darauf, dass Lamb, der in
# zwei Online-Kursen für die Delta State University in Cleveland,
# Mississippi, unterrichtete, bereits 300 Meilen zu dem Schulgelände
# gereist war, wo er nach Angaben der Polizei einen beliebten
# Geschichtsprofessor, Ethan Schmidt, an der Tür zu seinem Büro
# erschossen und getötet hat.
# =====================================================================
# Model: OPUS-MT
# Output: Es gab keinen Hinweis darauf, dass Lamb, der zwei Online-Kurse
# für die Delta State University in Cleveland, Mississippi,
# unterrichtete, bereits 300 Meilen zum Campus der Schule gereist war,
# wo die Polizei glaubt, er hätte einen gutgeliebten
# Geschichtsprofessor, Ethan Schmidt, in der Tür zu seinem Büro
# erschossen und getötet zu haben.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Es gab keine Anzeichen dafür, dass Lamb, der zwei Online-Kurse
# für die Delta State University in Cleveland, Mississippi, lehrte,
# bereits 300 Meilen zum Campus der Schule gereist hatte, wo die Polizei
# glaubt, er einen bekannten Historiker, Ethan Schmidt, in der Tür zu
# seinem Büro erschossen und erschossen habe.
#
# #####################################################################
#
# Example 15
# Input: Delta State University police chief Lynn Buford said
# university officials heard about the shooting at 10:18 a.m.
# Ground truth: Delta State University Polizeichef Lynn Buford
# sagte, dass Universitäts-Mitarbeiter das Schießen um 10:18 Uhr gehört
# haben.
# =====================================================================
# Model: OPUS-MT
# Output: Der Polizeichef der Delta State University, Lynn Buford,
# sagte, Universitätsbeamte hätten um 10:18 Uhr von den Schüssen gehört.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Lynn Buford, Polizeichef der Delta State University, sagte,
# Universitätsbeamte hörten von dem Schuss um 10:18 Uhr.
#
# #####################################################################
#
# Example 16
# Input: He said Lamb made the fateful 911 call sometime after
# that.
# Ground truth: Er sagte, dass Lamb den verhängnisvollen Notruf
# irgendwann danach gemacht hat.
# =====================================================================
# Model: OPUS-MT
# Output: Er sagte, dass Lamb irgendwann danach den schicksalhaften
# Notruf anrief.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Er sagte Lamb machte den Schicksalsruf 911 irgendwann danach.
#
# #####################################################################
#
# Example 17
# Input: By the end of the day, there would be one more death:
# Lamb took his own life as police closed in on him.
# Ground truth: Bis zum Ende des Tages gab es einen weiteren
# Tod: Lamm nahm sich das Leben, als die Polizei ihn einkesselte.
# =====================================================================
# Model: OPUS-MT
# Output: Am Ende des Tages würde es einen weiteren Tod geben: Lamm nahm
# sich sein Leben, als die Polizei ihn einschloss.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Am Ende des Tages würde es noch einen Tod geben: Lamm nahm
# sein eigenes Leben, als die Polizei sich auf ihn schloss.
#
# #####################################################################
#
# Example 18
# Input: A day after the school shooting forced students and
# faculty to hide behind locked doors, authorities were still trying to
# piece together what motivated Lamb.
# Ground truth: Einen Tag nach der Schießerei in der
# Universität, die Studenten und Dozenten dazu zwang, sich hinter
# verschlossenen Türen zu verstecken, versuchen die Behörden immer noch,
# sich ein Bild davon zu verschaffen, was Lamb motivierte.
# =====================================================================
# Model: OPUS-MT
# Output: Einen Tag nach dem Erschießen der Schule zwangen die Schüler
# und die Fakultät, sich hinter verschlossenen Türen zu verstecken,
# versuchten die Behörden immer noch, das zusammenzufassen, was Lamm
# motivierte.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Einen Tag nach dem Schulschießen zwangen Studenten und
# Lehrkräfte, sich hinter verschlossenen Türen zu verstecken, versuchten
# die Behörden immer noch, zusammenzufassen, was Lamb motiviert hatte.
#
# #####################################################################
#
# Example 19
# Input: The details released by investigators at both ends of
# the state as well as students and staff who knew him helped paint a
# picture of a talented but possibly troubled teacher.
# Ground truth: Die von den Ermittlern an beiden Enden des
# Staates veröffentlichten Details, wie auch das, was Studenten und
# Mitarbeiter, die ihn kannten, aussagten, half dabei, ein Bild von
# einem talentierten, aber möglicherweise schwierigen Lehrer zu
# zeichnen.
# =====================================================================
# Model: OPUS-MT
# Output: Die Details von Ermittlern an beiden Enden des Staates sowie
# Studenten und Mitarbeiter, die ihn kannten, halfen, ein Bild von einem
# talentierten, aber möglicherweise beunruhigten Lehrer zu malen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Die Angaben, die von Forschern an beiden Seiten des Staates
# sowie von Studenten und Mitarbeitern, die ihn kennen, veröffentlicht
# wurden, halfen, ein Bild eines talentierten, aber möglicherweise
# beunruhigten Lehrers zu malen.
#
# #####################################################################
#
# Example 20
# Input: Students said they looked forward to his class.
# Ground truth: Studenten sagten, dass sie sich auf seinen
# Unterricht freuten.
# =====================================================================
# Model: OPUS-MT
# Output: Die Schüler sagten, sie freuten sich auf seine Klasse.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Die Schüler sagten, dass sie auf seine Klasse freuen würden.
#
# #####################################################################
#
# Example 21
# Input: Police in Gautier, where Prentiss died, said he had no
# history of violence or criminal record.
# Ground truth: Die Polizei in Gautier, wo Prentiss starb,
# sagte, er habe keine Geschichte der Gewalt oder eine kriminelle
# Vorgeschichte.
# =====================================================================
# Model: OPUS-MT
# Output: Die Polizei in Gautier, wo Prentiss starb, sagte, er habe
# keine Vorgeschichte von Gewalt oder Vorstrafen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Die Polizei in Gautier, wo Prentiss starb, sagte, er habe
# keine Geschichte von Gewalt oder Straftaten.
#
# #####################################################################
#
# Example 22
# Input: Schmidt himself had included Lamb in a book he wrote
# where he acknowledged the "wonderful people" he shared his academic
# life with.
# Ground truth: Schmidt selbst hatte Lamb in einem von ihm
# geschriebenen Buch erwähnt, in dem er die "wunderbaren Menschen"
# erwähnte, mit denen er sein akademisches Leben teilte.
# =====================================================================
# Model: OPUS-MT
# Output: Schmidt selbst hatte Lamb in ein Buch aufgenommen, das er
# schrieb, wo er die "wunderbaren Menschen" anerkannte, mit denen er
# sein akademisches Leben teilte.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Schmidt selbst hatte Lamb in einem Buch, das er schrieb, in
# dem er die "wundervollen Menschen" anerkannte, mit denen er sein
# akademisches Leben teilte.
#
# #####################################################################
#
# Example 23
# Input: Both taught in the Division of Social Sciences and
# History, which lists 17 faculty members, and many students took
# courses from both.
# Ground truth: Beide unterrichteten in der Abteilung für
# Sozialwissenschaften und Geschichte, deren Lehrkörper 17 Mitglieder
# umfasst, und viele Studenten besuchten Kurse von beiden.
# =====================================================================
# Model: OPUS-MT
# Output: Beide unterrichteten in der Abteilung für Sozialwissenschaften
# und Geschichte, die 17 Fakultätsmitglieder auflistet, und viele
# Studenten nahmen Kurse von beiden.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Beide unterrichteten in der Abteilung für Sozialwissenschaften
# und Geschichte, die 17 Fakultätsmitglieder auflistt, und viele
# Studenten nahmen Kurse von beiden.
#
# #####################################################################
#
# Example 24
# Input: At the same time, there were some inclinations of
# problems.
# Ground truth: Zur gleichen Zeit gab es einige Neigungen zu
# problematischen Verhaltensweisen.
# =====================================================================
# Model: OPUS-MT
# Output: Gleichzeitig gab es einige Neigungen von Problemen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Gleichzeitig gab es einige Neigungen zu Problemen.
#
# #####################################################################
#
# Example 25
# Input: A student who praised Lamb, Brandon Beavers, said he
# also seemed agitated and jittery, "like there was something wrong with
# him."
# Ground truth: Ein Student, Brandon Beavers, der Lamb lobte,
# sagte, er schien auch ein wenig aufgeregt und nervös, "als ob etwas
# mit ihm falsch sei."
# =====================================================================
# Model: OPUS-MT
# Output: Ein Student, der Lamb, Brandon Beavers, lobte, sagte, dass er
# auch aufgeregt und zitternd schien, "als ob etwas mit ihm nicht
# stimmte."
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Ein Schüler, der Lamb lobte, Brandon Beavers, sagte, er schien
# auch aufgeregt und nervös, "wie es etwas falsch mit ihm war."
#
# #####################################################################
#
# Example 26
# Input: Another student, Mikel Sykes, said Lamb told him he was
# dealing with stress at the end of the 2014-15 academic year.
# Ground truth: Ein anderer Student, Mikel Sykes, sagte, dass
# Lamm ihm erzählt habe, dass er am Ende des akademischen Jahres 2014-15
# mit Stress zu tun hatte.
# =====================================================================
# Model: OPUS-MT
# Output: Ein anderer Student, Mikel Sykes, sagte Lamb sagte ihm, dass
# er es mit Stress am Ende des akademischen Jahres 2014-15.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Ein weiterer Student, Mikel Sykes, sagte, Lamb sagte ihm, dass
# er mit Stress am Ende des akademischen Jahres 2014-15 zu tun habe.
#
# #####################################################################
#
# Example 27
# Input: Lamb had earlier asked Delta State University for a
# medical leave of absence, saying he had a health issue of some sort.
# Ground truth: Lamb hatte zuvor die Delta State University um
# eine Beurlaubung aus gesundheitlichen Gründen gebeten und dabei
# gesagt, dass er irgendein gesundheitliches Problem habe.
# =====================================================================
# Model: OPUS-MT
# Output: Lamb hatte zuvor Delta State University für einen
# medizinischen Urlaub der Abwesenheit gefragt, sagte, er hatte eine
# gesundheitliche Frage von irgendeiner Art.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Lamb hatte früher die Delta State University um ein
# medizinisches Abwesenheitsurlaub gebeten, da er eine Art
# Gesundheitsproblem hatte.
#
# #####################################################################
#
# Example 28
# Input: This year, he was only teaching two online classes.
# Ground truth: In diesem Jahr unterrichtete er nur zwei Online-
# Kurse.
# =====================================================================
# Model: OPUS-MT
# Output: In diesem Jahr unterrichtete er nur zwei Online-Kurse.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Dieses Jahr lehrte er nur zwei Online-Kurse.
#
# #####################################################################
#
# Example 29
# Input: Recent changes in the university's hiring policies
# meant that the doctorate Lamb had worked so hard to earn would not
# guarantee him an automatic tenure track to become an assistant
# professor.
# Ground truth: Neueste Änderungen in der Beschäftigungspolitik
# der Universität bedeuteten, dass die Promotion, für die Lamb so hart
# gearbeitet hatte, für ihn keine Garantie für einen automatischen Weg
# zu einer Anstellung als Assistant-Professor darstellen würde.
# =====================================================================
# Model: OPUS-MT
# Output: Neuere Änderungen in der Einstellungspolitik der Universität
# bedeutete, dass die Promotion Lamb hatte so hart gearbeitet, um zu
# verdienen würde ihm nicht garantieren, eine automatische Tenure Track,
# um ein Assistent Professor zu werden.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Die jüngsten Änderungen in der Einstellungspolitik der
# Universität bedeuteten, dass die Promotion Lamb so hart gearbeitet
# hatte, um zu verdienen würde ihm nicht garantieren, eine automatische
# Laufbahn, um ein Assistenzprofessor zu werden.
#
# #####################################################################
#
# Example 30
# Input: University President William LaForge said he didn't
# know of any conflict between Lamb and Schmidt but "obviously there was
# something in Mr. Lamb's mind."
# Ground truth: Universitäts-Präsident William LaForge sagte, er
# wisse nichts von einem Konflikt zwischen Lamb und Schmidt, aber
# "natürlich gab es etwas in Mr Lambs Vorstellung."
# =====================================================================
# Model: OPUS-MT
# Output: University President William LaForge sagte, er wusste nicht
# von einem Konflikt zwischen Lamb und Schmidt, aber "offensichtlich gab
# es etwas in Mr. Lambs Geist."
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Universitätspräsident William LaForge sagte, er wußte keinen
# Konflikt zwischen Lamb und Schmidt, aber "es war offensichtlich etwas
# im Geist von Herrn Lamb."
#
# #####################################################################
#
# Example 31
# Input: Those are questions Lamb can no longer answer.
# Ground truth: Das sind Fragen, die Lamb nicht mehr beantworten
# kann.
# =====================================================================
# Model: OPUS-MT
# Output: Das sind Fragen, die das Lamm nicht mehr beantworten kann.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Diese Fragen kann Lamb nicht mehr beantworten.
#
# #####################################################################
#
# Example 32
# Input: After fleeing the campus, police later picked up Lamb's
# trail when he crossed back into Mississippi from Arkansas.
# Ground truth: Nach der Flucht aus dem Campus fand die Polizei
# später Lambs Spur, als er wieder in Mississippi aus Arkansas einfuhr.
# =====================================================================
# Model: OPUS-MT
# Output: Nachdem er aus dem Campus geflohen war, nahm die Polizei
# später Lambs Spur auf, als er von Arkansas zurück nach Mississippi
# kam.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Nach der Flucht vom Campus nahm die Polizei Lambs Spur auf,
# als er von Arkansas zurück in Mississippi überquerte.
#
# #####################################################################
#
# Example 33
# Input: Before he could be apprehended, Lamb killed himself
# with a single .38-caliber pistol in the backyard of a home about a
# mile south of his parents' home on the outskirts of Greenville,
# Mississippi, said Washington County Coroner Methel Johnson.
# Ground truth: Bevor er festgenommen werden konnte, tötete Lamb
# sich selbstmit einer .38 Kaliber Pistole im Hinterhof eines Hauses
# etwa eine Meile südlich seines Elternhauses am Stadtrand von
# Greenville, Mississippi, sagte Washington County Coroner Methel
# Johnson.
# =====================================================================
# Model: OPUS-MT
# Output: Bevor er verhaftet werden konnte, tötete Lamb sich mit einer
# einzigen 38-Kaliber-Pistole im Hinterhof eines Hauses etwa eine Meile
# südlich des Hauses seiner Eltern am Stadtrand von Greenville,
# Mississippi, sagte Washington County Coroner Methel Johnson.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Bevor er festgenommen werden konnte, tötete sich Lamb mit
# einer einzigen.38-Kaliber-Pistole im Hinterhof eines Hauses etwa eine
# Meile südlich von seinem Elternhaus am Rande von Greenville,
# Mississippi, sagte Washington County Coroner Methel Johnson.
#
# #####################################################################
#
# Example 34
# Input: His car was still running in the driveway.
# Ground truth: Sein Auto lief noch in der Einfahrt.
# =====================================================================
# Model: OPUS-MT
# Output: Sein Auto lief noch in der Einfahrt.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Sein Auto lief noch auf der Anfahrt.
#
# #####################################################################
#
# Example 35
# Input: It was not immediately clear why Lamb went to that
# home, though Johnson said she believes he knew the people who lived
# there.
# Ground truth: Es war nicht sofort klar, warum Lamm zu diesem
# Haus ging, aber Johnson sagte, dass sie glaubt, dass er die Leute
# kannte, die dort lebten.
# =====================================================================
# Model: OPUS-MT
# Output: Es war nicht sofort klar, warum Lamb zu diesem Haus ging,
# obwohl Johnson sagte, sie glaube, dass er die Menschen kannte, die
# dort lebten.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Es war nicht sofort klar, warum Lamb zu diesem Haus ging,
# obwohl Johnson sagte, dass sie glaubt, dass er die Menschen, die dort
# lebten, kannte.
#
# #####################################################################
#
# Example 36
# Input: Lamb grew up in the area.
# Ground truth: Lamb wuchs in der Gegend auf.
# =====================================================================
# Model: OPUS-MT
# Output: Lamm wuchs in der Gegend auf.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Das Lamm wuchs in der Gegend auf.
#
# #####################################################################
#
# Example 37
# Input: Lamb started working at the university, which has 3,500
# students in a city of about 12,000, in 2009 and taught geography and
# education classes.
# Ground truth: Lamb begann 2009 seine Arbeit an der
# Universität, die 3.500 Studenten in einer Stadt mit etwa 12.000
# Einwohnern hat und unterrichtete Geographie und Pädagogik.
# =====================================================================
# Model: OPUS-MT
# Output: Lamb begann 2009 an der Universität zu arbeiten, die 3.500
# Studenten in einer Stadt von etwa 12.000 hat, und unterrichtete
# Geographie und Bildung.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Lamb begann 2009 an der Universität zu arbeiten, die 3.500
# Studenten in einer Stadt von etwa 12.000 hat, und lehrte Geographie
# und Bildungsklassen.
#
# #####################################################################
#
# Example 38
# Input: He received a doctorate in education in the spring.
# Ground truth: Er promovierte im Frühjahr in Pädagogik.
# =====================================================================
# Model: OPUS-MT
# Output: Im Frühjahr wurde er in der Ausbildung promoviert.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Im Frühjahr erhielt er einen Doktortitel für Bildung.
#
# #####################################################################
#
# Example 39
# Input: One of Lamb's longtime friends described him as smart,
# charismatic and funny.
# Ground truth: Einer der langjährigen Freundinnen Lambs
# bezeichnete ihn als intelligent, charismatisch und lustig.
# =====================================================================
# Model: OPUS-MT
# Output: Einer von Lambs langjährigen Freunden beschrieb ihn als klug,
# charismatisch und lustig.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Einer der langjährigen Freunde Lambs beschrieb ihn als
# intelligent, charismatisch und lustig.
#
# #####################################################################
#
# Example 40
# Input: Carla Hairston said she was 15 and Lamb was 20 when
# they met through mutual friends.
# Ground truth: Carla Hairston sagte, sie war 15 und Lamm war
# 20, als sie sich durch gemeinsame Freunde trafen.
# =====================================================================
# Model: OPUS-MT
# Output: Carla Hairston sagte, sie sei 15 und Lamb 20, als sie sich
# durch gemeinsame Freunde trafen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Carla Hairston sagte, sie war 15 und Lamb war 20, als sie
# durch gegenseitige Freunde trafen.
#
# #####################################################################
#
# Example 41
# Input: She and her friends were in high school, and he was the
# cool older guy who tried for several years to teach her to play
# guitar.
# Ground truth: Sie und ihre Freunde waren in der High School,
# und er war der coole ältere Kerl, der einige Jahre versuchte, ihr das
# Gitarrenspiel beizubringen.
# =====================================================================
# Model: OPUS-MT
# Output: Sie und ihre Freunde waren in der Highschool, und er war der
# coole ältere Kerl, der für mehrere Jahre versuchte, ihr beizubringen,
# Gitarre zu spielen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Sie und ihre Freunde waren in der High School, und er war der
# coole ältere Kerl, der mehrere Jahre versuchte, sie zu lehren, Gitarre
# zu spielen.
#
# #####################################################################
#
# Example 42
# Input: He was quite the heartthrob back then.
# Ground truth: Er war damals der Frauenschwarm.
# =====================================================================
# Model: OPUS-MT
# Output: Er war damals ein ziemlicher Herzschlag.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Er war damals ganz der Herztrob.
#
# #####################################################################
#
# Example 43
# Input: All the girls would melt when he was around," said
# Hairston, now 40 and living in the Jackson suburb of Brandon.
# Ground truth: Alle Mädchen schmolzen dahin, wenn er da war",
# sagte Hairston, jetzt 40 und in der Jackson Vorstadt von Brandon
# wohnhaft.
# =====================================================================
# Model: OPUS-MT
# Output: Alle Mädchen würden schmelzen, wenn er in der Nähe war", sagte
# Hairston, jetzt 40 und lebt in der Jackson Vorort von Brandon.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Alle Mädchen würden sich verschmelzen, wenn er da war", sagte
# Hairston, jetzt 40 und lebt im Jackson-Vorort Brandon.
#
# #####################################################################
#
# Example 44
# Input: Lamb and Prentiss had apparently been dating for some
# time.
# Ground truth: Lamb und Prentiss waren offensichtlich einige
# Zeit zusammen.
# =====================================================================
# Model: OPUS-MT
# Output: Lamb und Prentiss waren anscheinend schon seit einiger Zeit
# zusammen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Lamb und Prentiss waren offenbar schon seit einiger Zeit
# miteinander verheiratet.
#
# #####################################################################
#
# Example 45
# Input: In the 911 call, Lamb said "I killed my wife," but
# there was no record of them ever marrying.
# Ground truth: In dem Notruf sagte Lamb "Ich habe meine Frau
# getötet", aber es gab keine Urkunde von einer Heirat.
# =====================================================================
# Model: OPUS-MT
# Output: Im Notruf sagte Lamb: "Ich habe meine Frau getötet", aber es
# gab keine Aufzeichnungen, dass sie jemals geheiratet haben.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Im 911-Anruf sagte Lamb: "Ich habe meine Frau getötet", aber
# es gab keine Aufzeichnung, dass sie jemals heirateten.
#
# #####################################################################
#
# Example 46
# Input: They had a dog named Lightning that lived with them at
# the brick house that backs up to a bayou in Gautier.
# Ground truth: Sie hatten einen Hund namens Lightning, der mit
# ihnen in dem Backstein-Haus lebte, das an einen Bayou in Gautier
# angrenzt.
# =====================================================================
# Model: OPUS-MT
# Output: Sie hatten einen Hund namens Lightning, der mit ihnen im
# Backsteinhaus wohnte, das bis zu einem Bayou in Gautier zurückreicht.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Sie hatten einen Hund namens Lightning, der bei ihnen im
# Ziegelhaus lebte, das auf eine Bayou in Gautier zurückgeht.
#
# #####################################################################
#
# Example 47
# Input: Police said the dog was OK.
# Ground truth: Die Polizei sagte, dass der Hund in Ordnung war.
# =====================================================================
# Model: OPUS-MT
# Output: Die Polizei sagte, der Hund sei in Ordnung.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Die Polizei sagte, der Hund sei in Ordnung.
#
# #####################################################################
#
# Example 48
# Input: Prentiss' ex-husband, Shawn O'Steen, said they divorced
# 15 years ago but remained friends and had a daughter who's now 19.
# Ground truth: Der Ex-Ehemann von Prentiss, Shawn O'Steen,
# sagte, sie seien vor 15 Jahren geschieden wurden, aber Freunde
# geblieben waren und eine Tochter hatten, die jetzt 19 Jahre alt war.
# =====================================================================
# Model: OPUS-MT
# Output: Prentiss' Ex-Mann Shawn O'Steen sagte, sie hätten sich vor 15
# Jahren geschieden, blieben aber Freunde und hatten eine Tochter, die
# jetzt 19 ist.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Prentiss Ehemann Shawn O'Steen sagte, dass sie vor 15 Jahren
# verheiratet waren, aber Freunde blieben und eine Tochter hatten, die
# jetzt 19 Jahre alt ist.
#
# #####################################################################
#
# Example 49
# Input: "She was completely devastated," O'Steen said of his
# daughter.
# Ground truth: "Sie war total am Boden zerstört", sagte O'Steen
# über seine Tochter.
# =====================================================================
# Model: OPUS-MT
# Output: "Sie war völlig verwüstet", sagte O'Steen von seiner Tochter.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: "Sie war völlig verwüstet", sagte O'Steen von seiner Tochter.
#
# #####################################################################
#
# Example 50
# Input: She and her mother were absolutely best friends.
# Ground truth: Sie und ihre Mutter waren absolut beste Freunde.
# =====================================================================
# Model: OPUS-MT
# Output: Sie und ihre Mutter waren absolut beste Freunde.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Sie und ihre Mutter waren absolut beste Freunde.
#
# #####################################################################
#
# Example 51
# Input: O'Steen said he had not met Lamb but heard through his
# daughter Abigail that Lamb was interested in music and played the
# blues.
# Ground truth: O'Steen sagte, er habe Lamb nie getroffen, aber
# durch seine Tochter Abigail habe er gehört, dass Lamb an Musik
# interessiert war und Blues spielte.
# =====================================================================
# Model: OPUS-MT
# Output: O'Steen sagte, er habe Lamb nicht getroffen, sondern durch
# seine Tochter Abigail gehört, dass Lamb an Musik interessiert sei und
# Blues spiele.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: O'Steen sagte, dass er Lamb nicht getroffen hatte, aber durch
# seine Tochter Abigail gehört hatte, dass Lamb an Musik interessiert
# war und den Blues spielte.
#
# #####################################################################
#
# Example 52
# Input: Lamb met Prentiss when he and Abigail both performed at
# a summer fair three years ago.
# Ground truth: Lamb traf Prentiss, als er und Abigail vor drei
# Jahren beide auf einem Sommer-Jahrmarkt auftraten.
# =====================================================================
# Model: OPUS-MT
# Output: Lamb traf Prentiss, als er und Abigail beide vor drei Jahren
# auf einer Sommermesse auftraten.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Lamb traf Prentiss, als er und Abigail vor drei Jahren auf
# einer Sommermesse auftrat.
#
# #####################################################################
#
# Example 53
# Input: Later, they played together in the occasional gig.
# Ground truth: Später spielten sie zusammen den einen oder
# anderen Gig.
# =====================================================================
# Model: OPUS-MT
# Output: Später spielten sie gelegentlich zusammen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Später spielten sie zusammen in der gelegentlichen Gig.
#
# #####################################################################
#
# Example 54
# Input: O'Steen said his daughter writes and sings her own
# music.
# Ground truth: O'Steen sagte, seine Tochter schreibt und singt
# ihre eigene Musik.
# =====================================================================
# Model: OPUS-MT
# Output: O'Steen sagte, seine Tochter schreibt und singt ihre eigene
# Musik.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: O'Steen sagte, seine Tochter schreibt und singt ihre eigene
# Musik.
#
# #####################################################################
#
# Example 55
# Input: Prentiss was a nurse who worked for various companies
# online.
# Ground truth: Prentiss war eine Krankenschwester, die für
# verschiedene Unternehmen online arbeitete.
# =====================================================================
# Model: OPUS-MT
# Output: Prentiss war eine Krankenschwester, die für verschiedene
# Unternehmen online arbeitete.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Prentiss war eine Krankenschwester, die für verschiedene
# Unternehmen online arbeitete.
#
# #####################################################################
#
# Example 56
# Input: Mike Shaffer, a bartender and sometimes entertainment
# coordinator at The Julep Room, a dimly lit bar near Gautier, said he
# last saw Lamb and Prentiss the night of Sept. 5, after Lamb had
# finished playing his guitar and harmonica for a sparse crowd.
# Ground truth: Mike Shaffer, ein Barkeeper und manchmal
# Unterhaltungs-Koordinator bei The Julep Room, einer schwach
# beleuchteten Bar in der Nähe von Gautier, sagte, dass er Lamb und
# Prentiss Night in der Nacht 5. September zum letzten Mal sah, nachdem
# Lamb sein Gitarren- und Mundharmonikaspiel beendet vor einem
# spärlichen Publikum beendet hatte.
# =====================================================================
# Model: OPUS-MT
# Output: Mike Shaffer, Barkeeper und manchmal Unterhaltungs-Koordinator
# im Julep Room, eine düster beleuchtete Bar in der Nähe von Gautier,
# sagte, er sah zuletzt Lamb und Prentiss in der Nacht vom 5. September,
# nachdem Lamb seine Gitarre und Mundharmonika für eine spärliche Menge
# gespielt hatte.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Mike Shaffer, ein Bartender und manchmal
# Unterhaltungskoordinator bei The Julep Room, einem dunkel beleuchteten
# Bar in der Nähe von Gautier, sagte, er habe Lamb und Prentiss zuletzt
# in der Nacht des 5. Sept. gesehen, nachdem Lamb seine Gitarre und
# Harmonika für eine dünne Menge gespielt hatte.
#
# #####################################################################
#
# Example 57
# Input: There was no sign of anything amiss.
# Ground truth: Es gab keine Anzeichen dafür, dass irgendetwas
# nicht stimmte.
# =====================================================================
# Model: OPUS-MT
# Output: Es gab keine Anzeichen dafür, dass etwas nicht stimmte.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Es gab keine Anzeichen für etwas Unrechtes.
#
# #####################################################################
#
# Example 58
# Input: "Just a happy couple," he said.
# Ground truth: "Einfach nur ein glückliches Paar", sagte er.
# =====================================================================
# Model: OPUS-MT
# Output: "Nur ein glückliches Paar", sagte er.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: "Nur ein glückliches Paar", sagte er.
#
# #####################################################################
#
# Example 59
# Input: We were cutting up and throwing one-liners at each
# other.
# Ground truth: Wir waren am Aufräumen und scherzten
# miteinander.
# =====================================================================
# Model: OPUS-MT
# Output: Wir haben uns geschnitten und eins-Liner aufeinander geworfen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Wir schneiden und werfen eine Linie auf die andere.
#
# #####################################################################
#
# Example 60
# Input: I mean, they both had a good sense of wit about them.
# Ground truth: Ich meine, sie hatten beide einen guten Sinn für
# Scherze.
# =====================================================================
# Model: OPUS-MT
# Output: Ich meine, beide hatten einen guten Witz über sie.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Ich meine, sie hatten beide ein gutes Verstand über sie.
#
# #####################################################################
#
# Example 61
# Input: Schmidt, the slain professor, directed the first-year
# seminar program and specialized in Native American and colonial
# history, said Don Allan Mitchell, an English professor at the school.
# Ground truth: Schmidt, der tote Professor, leitete das
# Erstsemester-Seminarprogramm und spezialisierte sich auf amerikanische
# Ureinwohner und koloniale Geschichte, sagte Don Allan Mitchell, ein
# Englisch-Professor an der Schule.
# =====================================================================
# Model: OPUS-MT
# Output: Schmidt, der ermordete Professor, leitete das erste Jahr
# Seminarprogramm und spezialisierte sich auf Indianer- und
# Kolonialgeschichte, sagte Don Allan Mitchell, ein englischer Professor
# an der Schule.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Schmidt, der ermordete Professor, leitete das erste Jahr
# Seminarprogramm und spezialisierte sich auf indigene amerikanische und
# koloniale Geschichte, sagte Don Allan Mitchell, ein englischer
# Professor an der Schule.
#
# #####################################################################
#
# Example 62
# Input: He was married and had three young children.
# Ground truth: Er war verheiratet und hatte drei kleine Kinder.
# =====================================================================
# Model: OPUS-MT
# Output: Er war verheiratet und hatte drei kleine Kinder.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Er war verheiratet und hatte drei kleine Kinder.
#
# #####################################################################
#
# Example 63
# Input: He studied at Emporia State University in Kansas and
# was president of his fraternity and student government.
# Ground truth: Er studierte an der Emporia State University in
# Kansas und war Präsident seiner Bruderschaft und des Studenten-
# Ausschusses.
# =====================================================================
# Model: OPUS-MT
# Output: Er studierte an der Emporia State University in Kansas und war
# Präsident seiner Bruderschaft und Studentenregierung.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Er studierte an der Emporia State University in Kansas und war
# Präsident seiner Brüderschaft und der Studentenregierung.
#
# #####################################################################
#
# Example 64
# Input: On the Delta State campus in Cleveland on Tuesday
# night, about 900 people, including faculty members, staff, students,
# and members of the community, attended a candlelight memorial.
# Ground truth: Auf dem Delta State Campus in Cleveland nahmen
# ...
# Model: mBART-50
# Output: Es war auch aus persönlichen Gründen bemerkenswert.
#
# #####################################################################
#
# Example 82
# Input: "We were sitting in the theater waiting for the royals
# to come in and I realize that the seat next to me is empty, and it
# dawns on me that Princess Diana is going to be sitting next to me," he
# said in a trailer for an upcoming documentary, "Back in Time."
# Ground truth: "Wir saßen im Theater warten auf die Royals, und
# ich merke, dass der Sitz neben mir leer ist, und es wird mir
# allmählich klar, dass Prinzessin Diana neben mir sitzen wird", sagte
# er in einem Trailer für einen bevorstehenden Dokumentarfilm "Back in
# Time".
# =====================================================================
# Model: OPUS-MT
# Output: "Wir saßen im Theater und warteten darauf, dass die Royals
# hereinkommen, und mir ist klar, dass der Platz neben mir leer ist, und
# es dämmert mir, dass Prinzessin Diana neben mir sitzen wird", sagte er
# in einem Trailer für eine kommende Dokumentation, "Back in Time".
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: "Wir saßen im Theater und warteten darauf, dass die Könige
# kamen, und ich erkannte, dass der Sitz neben mir leer ist, und es
# dawns auf mich, dass Prinzessin Diana neben mir sitzen wird", sagte er
# in einem Trailer für einen bevorstehenden Dokumentarfilm "Back in
# Time".
#
# #####################################################################
#
# Example 83
# Input: The movie starts and it occurs to me that I'm a fake
# yawn and an arm stretch away from being on a date with the Princess of
# Wales.
# Ground truth: Der Film beginnt, und es kommt mir in den Sinn,
# dass ich ein simuliertes Gähnen und eine Armeslänge davon entfernt
# bin, mit der Prinzessin von Wales bei einem Date zu sein.
# =====================================================================
# Model: OPUS-MT
# Output: Der Film beginnt und es kommt mir vor, dass ich ein
# gefälschtes Gähnen und ein Arm bin, der sich von einem Date mit der
# Prinzessin von Wales entfernt.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Der Film beginnt und es fällt mir auf, dass ich ein falscher
# Joch bin und ein Arm weit entfernt ist von einem Date mit der
# Prinzessin von Wales.
#
# #####################################################################
#
# Example 84
# Input: "Back in Time," a documentary about "Back to the
# Future," features interviews with Fox, Lea Thompson, and Christopher
# Lloyd, as well as director Robert Zemeckis, and executive producer
# Steven Spielberg.
# Ground truth: "Back in Time", eine Dokumentation über "Back to
# the Future", präsentiert Interviews mit Fox, Lea Thompson und
# Christopher Lloyd, sowie mit Regisseur Robert Zemeckis und dem
# Produzenten Steven Spielberg.
# =====================================================================
# Model: OPUS-MT
# Output: "Back in Time", eine Dokumentation über "Back to the Future",
# zeigt Interviews mit Fox, Lea Thompson und Christopher Lloyd sowie
# Regisseur Robert Zemeckis und Executive Producer Steven Spielberg.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: "Back in Time", ein Dokumentarfilm über "Back to the Future",
# enthält Interviews mit Fox, Lea Thompson und Christopher Lloyd sowie
# Regisseur Robert Zemeckis und Executive Producer Steven Spielberg.
#
# #####################################################################
#
# Example 85
# Input: "Back for the Future" premiered 30 years ago.
# Ground truth: "Back for the Future" hatte vor 30 Jahren
# Premiere.
# =====================================================================
# Model: OPUS-MT
# Output: "Back for the Future" uraufgeführt vor 30 Jahren.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: "Back for the Future" wurde vor 30 Jahren uraufgeführt.
#
# #####################################################################
#
# Example 86
# Input: "It really is for me," said Spielberg, "inarguably the
# greatest time travel movie ever put on film."
# Ground truth: "Es ist für mich wirklich", sagte Spielberg,
# "unstrittig der größte Zeitreise-Film, der jemals gedreht wurde."
# =====================================================================
# Model: OPUS-MT
# Output: "Es ist wirklich für mich", sagte Spielberg, "es ist wohl der
# beste Zeitreisefilm, den man je auf Film gedreht hat."
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: "Es ist wirklich für mich," sagte Spielberg, "der wohl größte
# Zeitreisefilm, der jemals auf Film gedreht wurde."
#
# #####################################################################
#
# Example 87
# Input: "Back in Time" will be available on VOD, DVD and in
# select movie theaters Oct.
# Ground truth: "Back in Time" wird auf VOD, DVD und in
# ausgewählten Kinos im Oktober zu sehen sein.
# =====================================================================
# Model: OPUS-MT
# Output: "Back in Time" wird auf VOD, DVD und in ausgewählten Kinos
# erhältlich sein Okt.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: "Back in Time" wird auf VOD, DVD und in ausgewählten Kinos ab
# Oktober erhältlich sein.
#
# #####################################################################
#
# Example 88
# Input: UN Chief Says There Is No Military Solution in Syria
# Ground truth: UN-Chef sagt, es gibt keine militärische Lösung
# in Syrien
# =====================================================================
# Model: OPUS-MT
# Output: UN-Chef sagt, es gibt keine militärische Lösung in Syrien
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: UN-Chef sagt, es gibt keine militärische Lösung in Syrien
#
# #####################################################################
#
# Example 89
# Input: Secretary-General Ban Ki-moon says his response to
# Russia's stepped up military support for Syria is that "there is no
# military solution" to the nearly five-year conflict and more weapons
# will only worsen the violence and misery for millions of people.
# Ground truth: Generalsekretär Ban Ki-Moon sagt, seine Antwort
# auf Russlands verstärkte militärische Unterstützung für Syrien ist:
# "Es gibt keine militärische Lösung" des fast fünf Jahre dauernden
# Konflikts, und mehr Waffen werden Gewalt und Elend für Millionen von
# Menschen nur verschlimmern.
# =====================================================================
# Model: OPUS-MT
# Output: Generalsekretär Ban Ki-moon sagt, dass seine Antwort auf
# Russlands verstärkte militärische Unterstützung für Syrien darin
# besteht, dass es "keine militärische Lösung" für den fast fünfjährigen
# Konflikt gibt und dass mehr Waffen die Gewalt und das Elend für
# Millionen von Menschen nur noch verschlimmern werden.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Generalsekretär Ban Ki-moon meint, seine Antwort auf Russlands
# verstärkte militärische Unterstützung für Syrien sei, dass es "keine
# militärische Lösung" für den fast fünfjährigen Konflikt gibt und dass
# mehr Waffen die Gewalt und das Elend von Millionen Menschen nur noch
# verschlimmern werden.
#
# #####################################################################
#
# Example 90
# Input: The U.N. chief again urged all parties, including the
# divided U.N. Security Council, to unite and support inclusive
# negotiations to find a political solution.
# Ground truth: Der UN-Chef fordert erneut alle Parteien,
# einschließlich des geteilten UN-Sicherheitsrats, auf, sich zu vereinen
# und integrative Verhandlungen zum Finden einer politischen Lösung zu
# unterstützen.
# =====================================================================
# Model: OPUS-MT
# Output: Der UN-Chef forderte erneut alle Parteien, einschließlich des
# geteilten UN-Sicherheitsrates, auf, die inklusiven Verhandlungen zu
# vereinen und zu unterstützen, um eine politische Lösung zu finden.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Der UN-Chef forderte erneut alle Parteien, einschließlich des
# geteilten UN-Sicherheitsrates, auf, sich zu vereinen und inclusive
# Verhandlungen zu unterstützen, um eine politische Lösung zu finden.
#
# #####################################################################
#
# Example 91
# Input: Ban told a news conference Wednesday that he plans to
# meet with foreign ministers of the five permanent council nations -
# the U.S., Russia, China, Britain and France - on the sidelines of the
# General Assembly's ministerial session later this month to discuss
# Syria.
# Ground truth: Ban sagte einer Pressekonferenz am Mittwoch,
# dass er plant, die Außenminister der fünf ständigen Mitglieds-Nationen
# des Rates - USA, Russland, China, Großbritannien und Frankreich - am
# Rande der Ministersitzung der Generalversammlung noch in diesem Monat
# zu treffen, um die Lage in Syrien zu diskutieren.
# =====================================================================
# Model: OPUS-MT
# Output: Ban sagte einer Pressekonferenz Mittwoch, dass er plant, mit
# Außenministern der fünf ständigen Rat Nationen - die USA, Russland,
# China, Großbritannien und Frankreich - am Rande der Ministertagung der
# Generalversammlung später in diesem Monat zu treffen, um Syrien zu
# diskutieren.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Ban sagte bei einer Pressekonferenz am Mittwoch, dass er sich
# mit den Außenministern der fünf ständigen Ratsstaaten - den USA,
# Russland, China, Großbritannien und Frankreich - auf der Seite der
# Ministersitzung der Generalversammlung später in diesem Monat treffen
# werde, um Syrien zu diskutieren.
#
# #####################################################################
#
# Example 92
# Input: He expressed regret that divisions in the council and
# among the Syrian people and regional powers "made this situation
# unsolvable."
# Ground truth: Er bedauerte, dass die Aufspaltungen im Rat und
# innerhalb des syrischen Volkes und der Regionalmächte "diese Situation
# unlösbar machen."
# =====================================================================
# Model: OPUS-MT
# Output: Er bedauerte, dass Spaltungen im Rat und unter dem syrischen
# Volk und den regionalen Mächten "diese Situation unlösbar gemacht
# haben".
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Er bedauerte, dass die Spaltungen im Rat und zwischen dem
# syrischen Volk und den regionalen Mächten "diese Situation unlösbar
# machten".
#
# #####################################################################
#
# Example 93
# Input: Ban urged the five permanent members to show the
# solidarity and unity they did in achieving an Iran nuclear deal in
# addressing the Syria crisis.
# Ground truth: Ban forderte die fünf ständigen Mitglieder auf,
# bei der Bewältigung der Krise in Syrien die gleiche Solidarität und
# Einheit zu zeigen, die sie bei der Erreichung eines nuklearen Deals
# mit dem Iran bewiesen haben.
# =====================================================================
# Model: OPUS-MT
# Output: Ban forderte die fünf ständigen Mitglieder auf, die
# Solidarität und Einheit zu zeigen, die sie bei der Verwirklichung
# eines iranischen Atomabkommens bei der Bewältigung der Syrien-Krise
# hatten.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Ban forderte die fünf ständigen Mitglieder auf, die
# Solidarität und Einheit zu zeigen, die sie bei der Erreichung eines
# Atomabkommens mit dem Iran bei der Bewältigung der Syrienkrise getan
# haben.
#
# #####################################################################
#
# Example 94
# Input: 8 Poll Numbers That Show Donald Trump Is For Real
# Ground truth: 8 Umfragewerte, die zeigen, dass Donald Trump
# ernst zu nehmen ist.
# =====================================================================
# Model: OPUS-MT
# Output: 8 Umfragezahlen, die zeigen, dass Donald Trump wirklich ist
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: 8 Umfragezahlen, die zeigen, Donald Trump ist für Real
#
# #####################################################################
#
# Example 95
# Input: Some have tried to label him a flip-flopper.
# Ground truth: Einige haben versucht, ihn als Flop zu
# brandmarken.
# =====================================================================
# Model: OPUS-MT
# Output: Einige haben versucht, ihm einen Flip-Flopper zu nennen.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Einige haben versucht, ihn als Flip-flopper zu bezeichnen.
#
# #####################################################################
#
# Example 96
# Input: Others have dismissed him as a joke.
# Ground truth: Andere haben ihn als einen Witz abgetan.
# =====================================================================
# Model: OPUS-MT
# Output: Andere haben ihn als Witz abgetan.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Andere haben ihn als Witze abgelehnt.
#
# #####################################################################
#
# Example 97
# Input: And some are holding out for an implosion.
# Ground truth: Und manche warten auf einen Zusammenbruch.
# =====================================================================
# Model: OPUS-MT
# Output: Und einige halten sich für eine Implosion auf.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Und einige drängen sich auf eine Implosion.
#
# #####################################################################
#
# Example 98
# Input: But no matter how some Republicans are trying to drag
# Donald Trump down from atop the polls, it hasn't worked (yet).
# Ground truth: Aber egal, wie einige Republikaner versuchen,
# Donald Trump von den oberen Rängen bei Umfragen nach unten zu ziehen,
# es hat (noch) nicht funktioniert.
# =====================================================================
# Model: OPUS-MT
# Output: Aber egal, wie einige Republikaner versuchen, Donald Trump von
# oben auf die Umfragen zu ziehen, es hat nicht funktioniert (noch).
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Aber egal, wie einige Republikaner versuchen, Donald Trump von
# der Spitze der Wahlen herunterzuziehen, es hat (noch) nicht
# funktioniert.
#
# #####################################################################
#
# Example 99
# Input: Ten of the last 11 national polls have shown Donald
# Trump's lead at double digits, and some are starting to ask seriously
# what it means for the real estate mogul's nomination chances.
# Ground truth: Zehn der letzten elf nationalen Umfragen zeigten
# Donald Trump im zweistelligen Bereich führen, und einige beginnen,
# sich ernsthaft zu fragen, was es für die Chancen der Nominierung des
# Immobilien-Moguls bedeutet.
# =====================================================================
# Model: OPUS-MT
# Output: Zehn der letzten 11 nationalen Umfragen haben Donald Trumps
# Führung bei zweistelligen Zahlen gezeigt, und einige beginnen
# ernsthaft zu fragen, was das für die Nominierungschancen des
# Immobilienmoguls bedeutet.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Zehn der letzten 11 nationalen Umfragen haben Donald Trumps
# Führung bei doppelten Ziffern gezeigt, und einige beginnen ernsthaft
# zu fragen, was es für die Nominierungschancen des Immobilienmakles
# bedeutet.
#
# #####################################################################
#
# Example 100
# Input: Of course, it's still early in the election cycle.
# Ground truth: Natürlich ist es noch zu früh in der
# Wahlperiode.
# =====================================================================
# Model: OPUS-MT
# Output: Natürlich ist es noch früh im Wahlzyklus.
# ---------------------------------------------------------------------
# Model: mBART-50
# Output: Natürlich ist es noch früh im Wahlzyklus.
#
# #####################################################################

# %% [markdown]
# ## Compute metrics

# %% [markdown]
# BLEU, or Bilingual Evaluation Understudy, is an evaluation metric used primarily for machine translation. It measures the similarity between a candidate translation and a set of reference translations, considering both the n-gram precision and a brevity penalty factor.
#
# $$BLEU = BP \times \exp\left(\sum_{n=1}^{N} w_n \log p_n\right)
# $$
#
# [Link](https://huggingface.co/spaces/evaluate-metric/google_bleu)
#
# [Info about Huggingface evaluate](https://huggingface.co/docs/evaluate/v0.4.0/en/package_reference/loading_methods#evaluate.load)
# <br> <br>
#
#
# METEOR is another automatic evaluation metric for machine translation that considers both precision and recall of the generated translation, as well as the harmonic mean of the two. It uses a more advanced alignment method, including synonyms and stemming, to better capture the meaning of the translation.
#
# $$METEOR = (1 - \gamma \times \text{Penalty}) \times \frac{P \times R}{\alpha P + (1 - \alpha) R}$$
# <br> <br>
# [Link zu Paper](https://www.aclweb.org/anthology/W05-0909)
#
# [Link zu METEOR on Hugging Face](https://huggingface.co/spaces/evaluate-metric/meteor)

# %%
# Compute the Google BLEU scores
references = [example["translation"]["de"] for example in dataset]
bleu_scores = []
for model_name, outputs in translations.items():
    bleu_score = bleu.compute(predictions=outputs, references=references)
    bleu_scores.append((model_name, round(bleu_score['google_bleu'], 4)))

# Create a DataFrame to store the model names and their Google BLEU scores using from_records
bleu_scores_df = pd.DataFrame.from_records(bleu_scores, columns=["Model", "Google BLEU Score"])

# Display the DataFrame
bleu_scores_df
# Out:
#       Model  Google BLEU Score
# 0  mBART-50             0.4647
# 1   OPUS-MT             0.4760

# %%
meteor = evaluate.load('meteor')
# Out:
# Downloading builder script:   0%|          | 0.00/6.81k [00:00<?, ?B/s]
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
meteor_scores = []
for model_name, outputs in translations.items():
    meteor_score = meteor.compute(predictions=outputs, references=references)
    meteor_scores.append((model_name, round(meteor_score['meteor'], 4)))

# %%
meteor_scores_df = pd.DataFrame.from_records(meteor_scores, columns=["Model", "METEOR Score"])
scores_df = bleu_scores_df.merge(meteor_scores_df, on="Model")
scores_df
# Out:
#       Model  Google BLEU Score  METEOR Score
# 0  mBART-50             0.4647        0.6825
# 1   OPUS-MT             0.4760        0.7087
