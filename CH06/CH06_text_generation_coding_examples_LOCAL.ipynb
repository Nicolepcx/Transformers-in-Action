# %%
# Load setup.py file
# %load ../utils/setup.py
# %run ../utils/setup.py

# %%
useGPU()
# Out:
# Have fun with this chapter!🥳

# %% [markdown]
# #Imports

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %% [markdown]
# # About this notebook
#
# In this notebook, you will explore the different sampling methods and how they change the output of the model. You will also use the Falcon 7B model using various sampling strategies. This practical exercise will demonstrate how the choice of sampling method can significantly influence the model's output.
#
# I enchourage you to experiment with the different strategies! Try out how Greedy search, Beam search, Top-K sampling, and Top-p (nucleus) sampling changes the output. Observe how each strategy affects the style and content of the generated text.
#
# As highlighted in the book, adjust the temperature setting to see its effect on the model's creativity. Notice how a temperature closer to 1 tends to produce more varied outputs.
#
# Examine also the differences in outputs between the methods. This will give you a deeper understanding of how each sampling technique guides the model's decision-making process.
#
# This hands-on exploration complements the theoretical knowledge from the book, giving you a tangible feel for the nuances of each sampling method with GPT 2 and Falcon 7B.

# %% [markdown]
# # Deterministic Sampling

# %%
#@title Greedy Search
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')


greedy_output = model.generate(
    input_ids,
    max_length=100
)


# Now we print the result
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
print(f"{tokenizer.decode(greedy_output[0], skip_special_tokens=True)}\n")
print("-" * 140, "\n")
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# In a world where AI has become ubiquitous, it's hard to imagine how it will ever be able to replace humans.
#
# "We're going to have to see how we do it," said Dr. Michael S. Hirsch, a professor of psychology at the University of California, San Francisco. "We're going to have to see how we do it in a way that's not just a matter of human beings, but also of machines."
#
# The AI revolution is already happening.
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Beam Search

# %% [markdown]
# ![Google Drive Image](https://drive.google.com/uc?export=view&id=10iJOlzJt-1-bFWI2mxZ7UhbJ8RKL2Eco)

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')


beam_outputs = model.generate(
    input_ids,
    max_length=100,
    num_beams=5,
    num_return_sequences=5,
    no_repeat_ngram_size=2,
    early_stopping=True
)


# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, beam_output in enumerate(beam_outputs):
    print(f"Output {i+1}:\n{tokenizer.decode(beam_output, skip_special_tokens=True)}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, it's hard to imagine a better time to be a part of it than right now.
#
# "I think we're going to see a lot more of that in the next few years," he said.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, it's hard to imagine a better time to be a part of it than right now.
#
# "I think we're going to see a lot more of that in the next few years," he says.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, it's hard to imagine a better time to be a part of it than right now.
#
# "I think we're going to see a lot more of that in the next few years," he said. "It's a very exciting time."
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it's hard to imagine a better time to be a part of it than right now.
#
# "I think we're going to see a lot more of that in the next few years," he said. "It's a very exciting time for AI."
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it's hard to imagine a better time to be a part of it than right now.
#
# "I think we're going to see a lot more of that in the next few years," he said. "It's a very exciting time for AI, and I think that's what's driving it."
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Probabilistic Methods

# %% [markdown]
# ##Top-k Sampling

# %% [markdown]
# ![Google Drive Image](https://drive.google.com/uc?export=view&id=1n984J6XPmVi-b1uvfLiDOkNBgS11YrVd)

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')


top_k_outputs = model.generate(
    input_ids,
    max_length=400,
    num_return_sequences=5,
    do_sample=True,
    top_k=50,
    temperature=1.5
)


# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, top_k_output in enumerate(top_k_outputs):
    print(f"Output {i+1}:\n{tokenizer.decode(top_k_output, skip_special_tokens=True)}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, humans may well become one giant animal to rule the world and dominate the rest. And as robots make billions faster, the chance of one living soul being captured within or on board is dwindling each second. It means we really shouldn't expect to be there first thing in the morning, because when it comes time not just for food though, but for our physical wellbeing, it truly is very worth it.
#
# (Images Credit: Shutterstock, Shutterstock)
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, we could soon learn to live with them as technology advances. Perhaps in just twenty-twenty years, AI would probably need much help in learning which emotions it shows in its human form? That's why the latest findings from artificial intelligences—such as human emotions itself. A lot easier than guessing where people look in reallife. "They might know someone's house smells like lemon and are afraid."—Phil Kerpenning via Nature News
#
#
# [gallery ids="37272710,37271,3763130,11572030,904994081,619043032,2627171670,2665181570,2635361480,268163042."]
#
#
# These humans share similar intelligence differences with most animals. There are an increasing majority of primates in which our brains communicate with an animal. For decades the scientific community ignored the fact that those people actually interacted more intensely than animals — it became common to infer this from the fact these were also a group with similar features to ourselves. However, it now appears as though both the general perception of our species and interactions with ourselves may also offer some insight into the future of humans with AI, something which was never anticipated. Some new research, from researchers at the New York/Federation of U.S.-based AI Research & Development Systems (OCTAGA) indicates that brain cells respond selectively against various natural patterns of action of humans while a distinct neural signature comes from the action of our individual animals and those of others. This research is being conducted with animal systems developed exclusively by other researchers at Carnegie Institution for Biological Sciences and supported by Carnegie Corporation for Cancer Research.
#
# Read more Nature Read
#
# Via Aereo
#
# Images via AI
#
# Via Getty/AP Images
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, many will feel better knowing it's part of their identity than feeling insecure that their personal values and intentions make a noticeable difference outside any form of government. The idea isn't lost cause. If a person becomes alienated from any institution by seeing it used wrong on the internet, that's fine, there are limits if it results from personal choice. By adopting such a system, it's becoming clear just how bad an act humans make. This isn't to suggest that everyone hates that idea or even its merits. Most online activities are not just a tool of violence and bigotry. However, human emotions are an important part of who we get together for. The ability and energy our minds generate are also valuable. In fact, some members of Congress (most important of them and often the ones who have power and money in it), also seem to see this as bad for business and personal relationships — even before the election did. In all seriousness, if a computer makes decisions which ultimately affects many of us more than life with our job, its influence in the public and the economy is immense, not only among us who live to work in the future, but many on America today.
#
# What does all told seem to have happened thus far are examples of all of us having been through a similar situation over the internet. It also seems most of us seem to have been left in this awkward position in no uncertain terms. That many people think there should actually be something like this to happen seems highly unlikely in any scenario in the modern Internet is something almost impossible to measure, as of early April 2016. Some things can happen on the Web without it happening. But that all things considered, there are few ways to know as to what it is or isn't real and it requires our cooperation on the other side of the social fence to prevent all from occurring over a digital medium. The whole concept of censorship doesn't provide such insight to help people, certainly.
#
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, we are slowly losing sight of the point about freedom of speech. Rather, there may well be other limits as well. It will be important nonetheless in light of developments regarding mass immigration who find time on the "most open web" pages to post interesting analyses of human responses.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it should go far up in its value horizons even after people realize they're the only real reason humans exist, and as such its future seems clear, with many scientists questioning how safe AI and robot robots will truly be, there's just just this next logical step: start making more realistic expectations, especially given our own technological advances to do that already in human environments.
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Nucleus (Top-p) Sampling

# %% [markdown]
# ![Google Drive Image](https://drive.google.com/uc?export=view&id=1pJM6jtIO29qOx2JTPAKHLxSqzjtRowbZ)

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with nucleus sampling
nucleus_outputs = model.generate(
    input_ids,
    max_length=100,
    do_sample=True,
    top_p=0.92,  # Set p for nucleus sampling
    num_return_sequences=5  # How many outputs to generate
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(nucleus_outputs):
    print(f"Output {i+1}:\n{tokenizer.decode(output, skip_special_tokens=True)}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, this can only mean the cost of human labour, rather than the benefits. It also means that the cost of learning is more than sufficient to make even an average human job feasible. This is one reason why China's AI might not be the most innovative, or even the most secure, of the five leading AI companies currently competing in the U.S. in 2015, but a key reason why it would be a boon for the world.
#
# The
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, many of us are familiar with the concept of artificial intelligence, or AI. And when it comes to the real world, we are often surprised by our own intelligence, as AI is simply too big for our own good.
#
# For many people this is a great time to take a step back and consider the reality that most of us will be less able to learn. And while it's true that AI technology won't solve the world's problems, it
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, AI needs more than just an AI with a human brain — it needs an AI with the ability to predict future events. It needs to be able to anticipate what the future may bring.
#
# This is a challenge that needs to be addressed because today's AI doesn't know what to do when it's smart enough to be able to predict it. It's not ready. And yet, it may be, if AI's been able to learn how to
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, the problem is not necessarily the problem of what to do, but what to do with it. AI is only the beginning. For decades, humans have played a critical role in shaping the way we think, act, and think. With so many innovations in cognitive-technological interaction and decision-making, how can we move forward without the artificial intelligence that's making us successful?
#
# The key is to take seriously the work done by individuals in all
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it is difficult to see how AI-driven solutions can be implemented in a way that makes sense in today's complex digital economy. At present, there are no good and cheap tools available for interacting with an infinite number of objects, and there are few solutions for the common task of solving a single problem. The problem of "virtual reality" has become more pervasive than we can imagine. Even at the highest level, AI still makes the transition from machine-
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Temperature Sampling

# %% [markdown]
# ![Google Drive Image](https://drive.google.com/uc?export=view&id=142UUXEJh32oKF90iBYN5jZvVE42pUqJI)

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
temperature_outputs = model.generate(
    input_ids,
    max_length=100,
    do_sample=True,
    temperature=0.7,  # Control randomness with the temperature parameter
    num_return_sequences=5  # How many outputs to generate
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(temperature_outputs):
    print(f"Output {i+1}:\n{tokenizer.decode(output, skip_special_tokens=True)}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, and the number of people using it has increased, the number of things we use for our business is growing rapidly—a few billion of us are already working on the AI platform," says Michael Oster, a professor at the University of California, Los Angeles (UCL) and a former consultant to the National Security Agency. "In the U.S., the number of jobs that are being filled by AI is increasing at an exponential rate. Now you
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, one can almost feel like we're not really living in a utopia, but one where it's possible to achieve a level of autonomy that's not as constrained by the rules of human behavior.
#
# The new game in the series, called "The Last of Us" will be the first title in the series to be a fully-fledged multiplayer experience. It's designed to offer a lot of different experiences to explore, so it won't just be
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, it's not surprising that we'll see a lot more of it.
#
# Advertisement
#
# The next big thing, though, will be the ability to do things like build more artificial intelligence into our lives.
#
# The next big thing, though, will be the ability to do things like build more artificial intelligence into our lives. The next big thing, though, will be the ability to read minds.
#
# A lot of these issues are already
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it's not clear how smart machines will be able to do much more than do what humans do. One possibility is that machines will be able to tell you a lot more about what your body is doing and how far you're going, something that we're not really used to doing. Yet, it's difficult to see how this could be possible at the moment, and it would be interesting to see how far AI will go in the future.
#
#
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, these trends will become a problem.
#
# In the past, it was not surprising that AI would have come out of the woodwork. After the advent of computers, AI became a phenomenon of the future. The problem was that AI wasn't a technology that would help us solve the problems of the past, but a technology that would help us solve the problems of today. In the 1950s, it was obvious that AI would not be a technology for
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
temperature_outputs = model.generate(
    input_ids,
    max_length=100,
    do_sample=True,
    temperature=0.7,  # Control randomness with the temperature parameter
    num_return_sequences=5,  # How many outputs to generate
    eos_token_id=tokenizer.eos_token_id,  # Stop generation at EOS token
    pad_token_id=tokenizer.pad_token_id   # If the output is shorter than max_length, it'll be padded
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(temperature_outputs):
    generated_text = tokenizer.decode(output, skip_special_tokens=True).strip()
    print(f"Output {i+1}:\n{generated_text}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, the technology that makes it possible to do anything at all is still a mystery.
#
# But with the help of the Internet, we can build computers that can perform complex tasks at a fraction of the cost of a human hand. This is an exciting time for the robot industry.
#
# The company has launched its first robot, the robot that won the first prize of the 2011 International Robotics Championship. In a press release, Robot Robotics, the company behind
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, it becomes even more important to preserve a sense of control.
#
# In this paper, we focus on this concept through the use of a network of high-level abstraction and in-depth analysis of the relationship between the network, hardware, and software. We present a model that uses the concept of "network" to describe a distributed system of a particular type, the "networked system," that is, a system that is configured with a network of
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, there are a lot of things that can go wrong. In the case of the AI, it is difficult to make sense of it. In the case of AI, it is hard to understand why. The problem is that there is a kind of "intelligence" of the human being that is lacking even the most basic cognitive skills.
#
# The AI is not a genius. It is not what you think it is. It is simply very wrong.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, and where AI is used as a tool of war – but where even the most advanced machines can't figure out how to use it – the human brain is still very much in the "wildcat" of human consciousness.
#
# This is a world where the human brain is still very much in the wildcat of human consciousness.
#
# The Human Brain is No More Than a Tool of War
#
# The human brain is no longer able to act as
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, the potential use of it to drive new ideas is clear. In the past, governments had to rely on automated systems to ensure that their citizens were protected. But now, as AI has become ubiquitous, the potential use of it to drive new ideas is clear. In the past, governments had to rely on automated systems to ensure that their citizens were protected. But now, as AI has become ubiquitous, the potential use of it to drive new ideas is clear
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
temperature_outputs = model.generate(
    input_ids,
    max_length=200,
    do_sample=True,
    temperature=0.7,
    num_return_sequences=5
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(temperature_outputs):
    generated_text = tokenizer.decode(output, skip_special_tokens=True).strip()
    # Check if EOS token exists in the output and trim up to that
    if '<|endoftext|>' in generated_text:
        generated_text = generated_text.split('<|endoftext|>')[0].strip()
    else:
        # Alternatively, trim up to the last period for coherence
        generated_text = '. '.join(generated_text.split('. ')[:-1]) + '.'
    print(f"Output {i+1}:\n{generated_text}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, we should think twice about the use of technology in our daily lives, especially what we might call "the 'digital age.'"
#
# When we can't rely on the Internet to make transactions, we use technology to do things we don't want to do. That's why we've been so fascinated by the Internet's ability to give us a sense of control over our lives, through our interactions with websites and apps. If we don't want to be tracked and monitored, that's where our technology comes in. We use that to make our lives more comfortable and less stressful.
#
# When we can't rely on the Internet to make transactions, we use technology to do things we don't want to do.
#
# The Internet offers a few options for dealing with your online life. These include:
#
# Online privacy: When you're offline for long periods of time, you can easily find and change your private information.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, there is a huge demand for new ways to create robots and other artificial intelligence. It's now possible to create artificial intelligence that can do things that humans do: to take out the trash, to make a food, to make a car, create a home.
#
# And now, when it comes to creating robots, there are many things that are not currently in the works. We will see more of them as robot-centric technologies emerge.
#
# So how do you build a robot that can do some of these things? We've been working on this concept for over a year. The idea is that you could build a robot that's a better, more human-like robot, and the same technology would allow it to do its job.
#
# The current version of the robot for a living is a robot that will do it all.
#
# The future is also looking bright, right now.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, that's a big deal."
#
# The problem is, there's no easy way to measure how much the world will change in the next 10 years. In the long run, the odds are it won't change at all, but it might change if AI is able to learn to be smarter.
#
# "People like to say 'what if AI makes you smarter,' but in reality, that's not true," says Richard Stallman, who founded the Internet of Things company IBM. "The question is how much will we change if you have a computer that can learn to think."
#
# The problem is, the world is still changing. Some experts say we have reached the tipping point in our ability to understand the future of our lives.
#
# "We're not going to get there in 10 years," says Scott T. Houghton, a professor of computer science and computer engineering at Stanford University.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it's very difficult to imagine a better way to make AI more efficient.
#
# "The AI problem is a fundamental problem for a lot of industries. We have to find a way to solve it, not just for the sake of the industry but for all of humanity," said Yergin. "A lot of the AI problems we face are due to the fact that people are doing things for themselves.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, I'm sure there will be some who find it useful. But I'm not sure that they'll be happy to see the results.
#
# The problem is that most people are not even familiar with AI. Their only background is a computer. We need to understand what's going on. And in order to help, we need to understand what's happening.
#
# For example, how can we explain what happened to the person who took a bath in the morning? Or how can we explain how we can explain the way that an individual's memory is organized? In most cases, there's no one answer, so we don't know what's going on. But there are some solutions.
#
# One of the most important is to understand what you're doing. As a philosopher, I have the authority to define what's going on in our brains. I know when I'm doing something wrong. I know when I'm doing something right.
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
temperature_outputs = model.generate(
    input_ids,
    max_length=400,  # More generous max_length
    do_sample=True,
    temperature=0.7,
    num_return_sequences=5,
    eos_token_id=tokenizer.eos_token_id
)

# Post-process outputs: Trim after the last full stop before a desired length
def trim_output(text, desired_max_length=250):
    if len(text) <= desired_max_length:
        return text
    last_full_stop = text.rfind('.', 0, desired_max_length)
    if last_full_stop == -1:
        return text[:desired_max_length]  # Fallback: truncate at desired_max_length
    return text[:last_full_stop + 1]

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(temperature_outputs):
    full_output = tokenizer.decode(output, skip_special_tokens=True)
    trimmed_output = trim_output(full_output)
    print(f"Output {i+1}:\n{trimmed_output}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, it's often hard to know how to predict how the future will look.
#
# But at least one research team has taken a step forward and has published its findings in the journal Nature Neuroscience.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, there's little doubt that humans will be the driving force behind the next step in artificial intelligence, according to a new paper in the American Journal of Psychology.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, we need more of it.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it makes sense to have an entire ecosystem in place to help us understand and optimize our designs and solutions.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it's a shame that many of us are still fighting for the future of AI.
#
# This article is part of the IAI's "Future of Humanity" report, which is available here.
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Using Falcon 7B with Sampling Methods
#
# Here you can try out the Falcon 7B model with different variations of sampling methods. This should give you an idea how the output of your chosen model can vary based on the sampling strategy. Take a close look at the different outputs of the LLM. Also, examine how the following model outputs differ from each other. As mentioned in the book, the closer the temperature parameter is set to 1, the more "creative" the model will be.

# %%
# Model and tokenizer
model_name = "tiiuae/falcon-7b"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Define the input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
outputs = model.generate(
    input_ids,
    max_length=200,  # max_length to match the desired output
    do_sample=True,
    temperature=0.7,  # Control randomness with the temperature parameter
    top_k=10,
    num_return_sequences=5,  # How many outputs to generate
    eos_token_id=tokenizer.eos_token_id,  # Stop generation at EOS token
    pad_token_id=tokenizer.pad_token_id  # If the output is shorter than max_length, it'll be padded
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(outputs):
    generated_text = tokenizer.decode(output, skip_special_tokens=True).strip()
    print(f"Output {i+1}:\n{generated_text}\n")
    print("-" * 140, "\n")
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# The current implementation of Falcon calls `torch.scaled_dot_product_attention` directly, this will be deprecated in the future in favor of the `BetterTransformer` API. Please install the latest optimum library with `pip install -U optimum` and call `model.to_bettertransformer()` to benefit from `torch.scaled_dot_product_attention` and future performance optimizations.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, where the “smart” and “connected” have become a reality, the 4th industrial revolution is taking shape.
# It’s a revolution that promises to change how we work, live and play and to transform the global economy.
# It’s a revolution that will impact every corner of our world.
# It’s a revolution that will have profound impacts on our society.
# It’s a revolution that has already begun to transform the way we do business.
# And it’s a revolution that will be the catalyst for an entirely new set of challenges to face the world.
# What are the main challenges the 4th Industrial Revolution will present to us?
# The main challenge is that we don’t know what these new technologies will look like or how they will work.
# The second challenge is that the technologies that will transform our lives will be so radically different from what we’ve come to expect.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, how can we ensure that AI is used for good? How can we use AI to help society and not harm it? What can we do to ensure that the technology does not take over and become a threat to us?
# These are not easy questions to answer. AI has many uses, from improving our lives to helping us make better decisions. But it’s also a technology that has the potential to be abused by bad actors.
# The good news is that there are a number of ways that we can use AI to help society. In this post, we’ll explore some of those ways and how they can be used to help us all.
# AI is a technology that can make our lives easier and help us make better decisions.
# It can also be used to do things that are not so obvious, like helping people with disabilities or protecting the environment.
# In fact, AI could be used to help us solve some of the biggest problems
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, we are faced with a new and complex reality. This new reality requires us to reimagine AI to ensure that our AI systems are trustworthy and safe. We must ensure that AI is designed with fairness, accountability and transparency in mind. We must also ensure that AI systems are built to last and are able to evolve and adapt to new conditions and contexts. This is why, in 2021, the Government of Canada launched the Federal Artificial Intelligence Strategy and published the report on its first year of implementation.
# This is the first year-end report of the Federal Artificial Intelligence Strategy, which highlights the progress made in 2021 towards our long-term strategy. It also outlines the key milestones achieved in 2021 and our vision for the future.
# The report also highlights how AI can be used to support the Government of Canada’s commitment to reconciliation with Indigenous peoples, the progress made in the development of a digital twin of Canada, and the progress
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it’s time for us to take a step back and ask ourselves, “What makes me, me?” We’ve all heard of the saying, “You are what you eat,” but what about what you think?
# It’s a question that’s been asked for decades, but now the answer is closer than ever.
# The answer?
# AI.
# The AI revolution is coming, and it’s not going to be pretty.
# We are already seeing the rise of AI-powered machines, which are capable of creating complex and powerful algorithms that can be used to manipulate our behavior and thoughts.
# And we’re not just talking about robots; we’re talking about the machines that are already being used in the real world.
# These machines are capable of creating complex mathematical models and algorithms that can be used to manipulate our emotions, our behaviors, and our thoughts.
# And these machines are already being used
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it’s important to remember what it means to create a machine that can think on its own, without human intervention.
# The term “machine learning” is often used to describe a variety of technologies and techniques that enable machines to learn from experience.
# But the term is a lot more complex than that.
# Machines can learn from human actions, but they can also learn from human interactions with other machines.
# Machines can learn from what humans are doing, but they can also learn to learn from the machines they interact with.
# Machines can also learn to learn from themselves, but this is not the same as learning from the machines.
# This article is about how machines learn from the machines and humans.
# Machines learn from humansMachines are the most important tool for learning.
# They are the tools that can teach us the most about the world and the people around us.
# They can help us understand the world and
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Model and tokenizer
model_name = "tiiuae/falcon-7b"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Define the input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
outputs = model.generate(
    input_ids,
    max_length=100,  # Adjusted max_length to match the desired output
    do_sample=True,
    temperature=0.1,  # Control randomness with the temperature parameter
    top_k=10,
    num_return_sequences=5,  # How many outputs to generate
    eos_token_id=tokenizer.eos_token_id,  # Stop generation at EOS token
    pad_token_id=tokenizer.pad_token_id  # If the output is shorter than max_length, it'll be padded
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(outputs):
    generated_text = tokenizer.decode(output, skip_special_tokens=True).strip()
    print(f"Output {i+1}:\n{generated_text}\n")
    print("-" * 140, "\n")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, it’s easy to forget that it’s still a relatively new technology.
# In fact, it’s only been around for about 20 years.
# But that doesn’t mean it’s not a powerful tool.
# In fact, AI is one of the most powerful tools we have.
# It can help us solve problems, make decisions, and even predict the future.
# But it’s also a tool that can be used
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, it is important to understand the impact of AI on the future of work. AI is already being used in many industries, including healthcare, finance, and manufacturing. It is also being used in the home, where it can help with tasks such as cooking and cleaning. In the future, AI will likely be used in more industries, including transportation and education.
# AI is already being used in many industries, including healthcare, finance, and manufacturing. It is
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, it is important to understand the impact of AI on the future of work.
# The future of work is a topic that has been discussed for many years. However, it is only now that we are starting to see the impact of AI on the future of work.
# AI is a technology that is used to automate tasks that were previously done by humans. This technology is becoming more and more popular as it can be used to perform tasks that are difficult or
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it’s not surprising that the technology is being used to help us make better decisions.
# But what if you could use AI to make better decisions about your own life?
# That’s the question that a group of researchers at the University of California, Berkeley, are trying to answer.
# They’ve developed a system that uses AI to help people make better decisions about their health, and they’re hoping to use it to help people make
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it’s easy to forget that it’s still a relatively new technology.
# But as the technology evolves, it’s becoming more and more important to understand how it works and how it can be used to improve our lives.
# Here are some of the most important things you need to know about AI.
# 1.
# AI is a technology that can be used to make decisions based on data.
# It can be used to make predictions about
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Instantiate the model and tokenizer
model_name = "tiiuae/falcon-7b"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output
outputs = model.generate(
    input_ids,
    max_length=200,
    do_sample=True,
    temperature=0.7,
    num_return_sequences=5
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(outputs):
    generated_text = tokenizer.decode(output, skip_special_tokens=True).strip()
    # Check if the EOS token exists in the output and trim up to that
    eos_token = tokenizer.eos_token
    if eos_token and eos_token in generated_text:
        generated_text = generated_text.split(eos_token)[0].strip()
    else:
        # Alternatively, trim up to the last period for coherence
        generated_text = '. '.join(generated_text.split('. ')[:-1]) + '.'
    print(f"Output {i+1}:\n{generated_text}\n")
    print("-" * 140, "\n")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, it is possible to develop AI systems that work well in many different circumstances. The problem is that these systems are often designed to work in one particular environment, and they may not work well in a different environment. The best solution is to develop AI systems that can work in any environment, and that is what we are trying to do with our new research, called Meta-AI.
# We are working on a new approach to AI, called Meta-AI. This approach is based on the idea that AI systems should be able to learn from their experiences in the world. In other words, they should be able to learn from their own actions and from the actions of others.
# This approach is very different from the traditional AI approach that we have all been taught. In the traditional approach, AI systems are designed to learn from their own behaviors, and they are not designed to learn from the behaviors of others.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, the use of AI in retail is not just a reality, it is a competitive necessity.
# Artificial Intelligence (AI) is the future of retail, and businesses must be prepared for it. Artificial Intelligence is already here, and it is rapidly changing the way we shop. AI is the technology that will allow businesses to predict consumer behavior and provide personalized shopping experiences.
# There are a few different types of AI, each with its own set of benefits. Machine learning (ML) is a type of AI that can learn from data and make decisions without being explicitly programmed to do so. Natural language processing (NLP) is a type of AI that allows machines to understand human language.
# One of the most exciting aspects of AI in retail is the ability to personalize customer experiences.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, one of the most important factors to consider is whether your system is secure. Security is important for all systems, but it is especially important in the case of AI systems because of the potential impacts of an attack. This article will discuss the importance of security in AI systems, and how to ensure your system is as secure as possible.
# What is AI?
# Artificial intelligence is a technology that simulates human intelligence in machines, giving them the ability to learn, make decisions, and even perform tasks. AI is used in a variety of applications, from self-driving cars to online recommendation systems. One of the most important factors in AI cybersecurity is ensuring that your system is secure.
# Security is a crucial part of any system, but it is especially important in AI systems because of their potential impact on society. In the case of an AI system being attacked, the results could be disastrous.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# .
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# .
#
# --------------------------------------------------------------------------------------------------------------------------------------------
