# %% [markdown]
# ## Open notebook in:
# | Colab                                 |  Gradient                                                                                                                                         |
# |:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Nicolepcx/Transformers-in-Action/blob/main/CH06/CH06_text_generation_coding_examples.ipynb)                                              | [![Gradient](https://assets.paperspace.io/img/gradient-badge.svg)](https://console.paperspace.com/github/Nicolepcx/Transformers-in-Action/blob/main/CH06/CH06_text_generation_coding_examples.ipynb)|

# %%
# Clone repo, if it's not already cloned, to be sure all runs on smoothly
# on Colab, Kaggle or Paperspace
import os

if not os.path.isdir('Transformers-in-Action'):
    # !git clone https://github.com/Nicolepcx/Transformers-in-Action.git
else:
    print('Repository already exists. Skipping clone.')


current_path = %pwd
if '/Transformers-in-Action' in current_path:
    new_path = current_path + '/utils'
else:
    new_path = current_path + '/Transformers-in-Action/utils'
# %cd $new_path
# Out:
# Cloning into 'Transformers-in-Action'...
# remote: Enumerating objects: 279, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 279 (delta 62), reused 71 (delta 29), pack-reused 152
# Receiving objects: 100% (279/279), 2.24 MiB | 7.11 MiB/s, done.
# Resolving deltas: 100% (134/134), done.
# /content/Transformers-in-Action/utils

# %% [markdown]
# # Install requirements

# %%
from requirements import *

# %%
install_base_packages()
install_required_packages_ch06()
# Out:
# Installing base requirements...
#
# ✅ transformers==4.26.1 installation completed successfully!
#
# ✅ datasets==2.10.1 installation completed successfully!
#
# Installing chapter 6 requirements...
#
# ✅ accelerate==0.26.1 installation completed successfully!

# %%
from setup import *

# %%
useGPU()
# Out:
# Have fun with this chapter!🥳

# %% [markdown]
# #Imports

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

# %% [markdown]
# # About this notebook
#
# In this notebook, you will explore the different sampling methods and how they change the output of the model. You will also use the Falcon 7B model using various sampling strategies. This practical exercise will demonstrate how the choice of sampling method can significantly influence the model's output.
#
# I enchourage you to experiment with the different strategies! Try out how Greedy search, Beam search, Top-K sampling, and Top-p (nucleus) sampling changes the output. Observe how each strategy affects the style and content of the generated text.
#
# As highlighted in the book, adjust the temperature setting to see its effect on the model's creativity. Notice how a temperature closer to 1 tends to produce more varied outputs.
#
# Examine also the differences in outputs between the methods. This will give you a deeper understanding of how each sampling technique guides the model's decision-making process.
#
# This hands-on exploration complements the theoretical knowledge from the book, giving you a tangible feel for the nuances of each sampling method with GPT 2 and Falcon 7B.

# %% [markdown]
# # Deterministic Sampling

# %%
#@title Greedy Search
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')


greedy_output = model.generate(
    input_ids,
    max_length=100
)


# Now we print the result
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
print(f"{tokenizer.decode(greedy_output[0], skip_special_tokens=True)}\n")
print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# In a world where AI has become ubiquitous, it's hard to imagine how it will ever be able to replace humans.
#
# "We're going to have to see how we do it," said Dr. Michael S. Hirsch, a professor of psychology at the University of California, San Francisco. "We're going to have to see how we do it in a way that's not just a matter of human beings, but also of machines."
#
# The AI revolution is already happening.
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Beam Search

# %% [markdown]
# ![Google Drive Image](https://drive.google.com/uc?export=view&id=10iJOlzJt-1-bFWI2mxZ7UhbJ8RKL2Eco)

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')


beam_outputs = model.generate(
    input_ids,
    max_length=100,
    num_beams=5,
    num_return_sequences=5,
    no_repeat_ngram_size=2,
    early_stopping=True
)


# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, beam_output in enumerate(beam_outputs):
    print(f"Output {i+1}:\n{tokenizer.decode(beam_output, skip_special_tokens=True)}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, it's hard to imagine a better time to be a part of it than right now.
#
# "I think we're going to see a lot more of that in the next few years," he said.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, it's hard to imagine a better time to be a part of it than right now.
#
# "I think we're going to see a lot more of that in the next few years," he says.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, it's hard to imagine a better time to be a part of it than right now.
#
# "I think we're going to see a lot more of that in the next few years," he said. "It's a very exciting time."
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it's hard to imagine a better time to be a part of it than right now.
#
# "I think we're going to see a lot more of that in the next few years," he said. "It's a very exciting time for AI."
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it's hard to imagine a better time to be a part of it than right now.
#
# "I think we're going to see a lot more of that in the next few years," he said. "It's a very exciting time for AI, and I think that's what's driving it."
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Probabilistic Methods

# %% [markdown]
# ##Top-k Sampling

# %% [markdown]
# ![Google Drive Image](https://drive.google.com/uc?export=view&id=1n984J6XPmVi-b1uvfLiDOkNBgS11YrVd)

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')


top_k_outputs = model.generate(
    input_ids,
    max_length=400,
    num_return_sequences=5,
    do_sample=True,
    top_k=50,
    temperature=1.5
)


# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, top_k_output in enumerate(top_k_outputs):
    print(f"Output {i+1}:\n{tokenizer.decode(top_k_output, skip_special_tokens=True)}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, it's tempting to see it as inevitable, especially to see people like them. Some will argue that they should make good use of this technological leap to start a new society. They have been, but they might have fewer kids in the future. There is a growing public understanding that when there isn't enough children to do productive work, then AI could at worst be used to improve their lives.
#
# Perhaps we are in that area too, but there are still ways AI could benefit you to be better. You can take our suggestion for creating better software and use it to make a difference against AI: get the AI off the shelf. Take the opportunity to support better people on both the web and at an ethical level. Go beyond talking over social media: you could take a step further using that to connect yourself online.
#
# But even more important is using this opportunity as an impetus for future activism when these social tools aren't necessarily needed anymore to fight. As a young girl with Alzheimer syndrome, there is growing interest online. The AI that is creating online awareness about autism isn't likely much different to the software used for Alzheimer diagnosis or even the other ways of being cognitively competent who aren't affected today in the way Alzheimer and stroke do. People think that's an evil goal but to be quite clear, it is not such an idea when you think of the role of mental enhancement, or in general human enhancement through an earlyudding and early understanding of brain activity or learning. But that just isn't so! Instead the motivation behind promoting awareness, for more meaningful communication and in developing greater cognitive engagement are very different from what it's usually used on their own computer monitors.
#
# Even today with so much going out between Interstate 75 and this very very old airport near downtown Cleveland, people needn't take our advice any expliitely. In fact in doing so I'm trying to give my readers in particular good reasons rather than just the
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, I fear it may only be as good for society as our scientific tools for fighting pollution, says RethinkIQ, a research group at Cornell University Cambridge: "AI's future should remain more in the realm of machine knowledge than our lives have been but to this I add only a tiny fraction at most—fewer than 1 percent [of what a person in today] still does as we know it. AI should allow us an unprecedented access." One of his key concepts, however, has the power to "turn science and the arts into art-making machines" through "the democratization of social work" and human agency — creating, say, careers in the arts and education that make it possible for people all over the world to write art their days are up with, including with little thought or concern for money or their welfare.
#
# It is worth mentioning this isn't going to be a post on Wikipedia. I only know at that point the answer. In fact I have found plenty to compare against, such as Mark Udvar-Hazy's "Robber and robot," and a few that don't require that you read that. (Hazy calls Robber Robots "an artful metaphor for AI," despite those claims.) This was recently shown for the debut of new series "Human AI, Robbers, Robots."
#
# We're only six episodes inside. See these two YouTube videos:
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, it looks incredibly risky to experiment for longer and less than optimal periods of time. If you know your subjects are going to spend an amount of days, hour-long intervals until exhaustion, it works for sure.
#
# Do experimenters make any mistakes? Let's go through how best to control for known confounding variables that exist when you are doing experiments: (i) do experiments that will not necessarily lead to more work to follow until you find work that's good or bad, and (ii) try doing more and not worse work after you know this risk exists. When designing long experimental work schedules like that — with each experiment having a very specific end goal—be prepared to adjust your training for the different challenges.
#
# A great lesson comes out when a project, if done right, has become an impossible and impossible achievement: how can you make it a true challenge every time it is started? And, in fact, you should be able to accomplish this every time you start:
#
# For each task, experiment (including, in most experiments, tasks completed and no tasks completed yet); choose a subject that will perform in the appropriate range of situations; evaluate his best performance and performance; write down each individual's achievements to help test his or her abilities; assess for potential bias. If any of participants are too much (at least 90%) for any given experiment (or for any experiment that does not offer anything significant on the results, then try finding a subject who you feel isn't, too), write down if such potential biases manifest, and determine if at least 20% of possible mistakes that fail might lead a human on successful. Consider possible outcomes that are Apache Enterprise available during a week or two, and may give you valuable hints as to how to proceed on the more expensive task at hand. As an experienced system and human being, if one experiment can offer anything in some sort of experimental way it is worthwhile to take notes. For
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, we should consider all humans to only the very high frequencies of the radio frequencies used during production or transmission; these frequencies can only be affected through manual operation by a person wielding any device, usually a computer, other than an individual radio that controls the voice and computer.
#
#
# We are now closer than ever before to establishing that a computer computer at the atomic level could not do everything we seek, without the human being taking responsibility for performing the work he would otherwise perform. This might in essence imply an enormous degree of automation to replace any need, any problem or function in those computers would be eliminated, as we could instead perform a more or less complex, efficient, yet efficient task or create many new things and different environments as if these functions were more or less the same. That would allow the entire enterprise to run. And it is, of course, entirely possible -- of course -- that these machines will simply grow exponentially and perform every job any way they must or need to. However -- because of the enormous scope the computers present -- most of the time they represent just how far or more efficient we all already must already have been.
#
# - Michael
#
# Dear Mark Wierziger
#
# The following text shows that as early computers were operating so much faster than they did when created at the scale needed, the development of a computer without an individual, individual user has dramatically more or less eliminated most tasks.
#
# Let us assume our first example assumes a given computer runs in memory no one cares a single thing about. We know nothing about the individual computer having control, who owns it, or how long it took. Is there a computer with special operating specifications allowing it to run? Is there the capability, for instance, to operate two of a class at once: a systemactivation program to remove unwanted processes based on memory shortages which could otherwise cause significant delay in running time (if its code is executed correctly by every operating-system process
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, few are taking advantage and giving them new ways of living. The biggest new technology, Facebook, appears this Monday morning, which makes it this hard to ignore the immense changes that are possible around it with a digital platform.
#
# At its most rudimentary form I had nothing to lose, everything that matters to us would fall to some kind of computer program if I had to try to navigate a million other things simultaneously to be left alone. Every new feature like YouTube would instantly start broadcasting its own content on YouTube (a few weeks earlier Google already brought this feature for itself). Like we heard in 2015 we could navigate that web without worrying about how to find another way out and that's what's happening, too. At no longer, we must navigate every site and every channel that takes up valuable space in our heads in less time or that we are constantly searching in the data store. So all things to think along will simply turn their attention towards this new digital reality, with real content just waiting patiently for their day in the flesh before there is any room for it to explode into a swarm on steroids like this. All we must care about is keeping track of where we are right now and who the big trends are that we, the individual and what the community, the businesses should do differently.
#
# The rise of self discovery
#
# There is something remarkable about having both hands on these spaces, but that does not change the power structure; the more people can be involved through all these new media portals, and it just takes longer and more effort to build, the less we're always left exposed and able to connect to our needs Heck there's nothing more frustratingly difficult for humans. You'll feel better every minute because one click at an e-commerce store allows more data back onto your social networks at greater efficiency than when you were still online. Every little drop of money gives everyone a second chance to connect back into reality (when every button was pushed
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Nucleus (Top-p) Sampling

# %% [markdown]
# ![Google Drive Image](https://drive.google.com/uc?export=view&id=1pJM6jtIO29qOx2JTPAKHLxSqzjtRowbZ)

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with nucleus sampling
nucleus_outputs = model.generate(
    input_ids,
    max_length=100,
    do_sample=True,
    top_p=0.92,  # Set p for nucleus sampling
    num_return_sequences=5  # How many outputs to generate
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(nucleus_outputs):
    print(f"Output {i+1}:\n{tokenizer.decode(output, skip_special_tokens=True)}\n")
    print("-" * 140, "\n")
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, this is not the case.
#
# The most recent example is Google's own self-driving car, which, at the time of this writing, was able to successfully navigate a highway in Los Angeles without any human intervention. Now that its self-driving car is on the road, it's almost certain that autonomous driving will be the next major industry.
#
# That's bad news for the American auto industry, who have been trying to make it safe
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, there will be little reason to keep up.
#
# If anything, the most obvious way to avoid using AI systems is to avoid creating them, and to instead use them as tools to create tools that we're not meant to be using. The only thing that's a great way to avoid this is to develop your own personal AI AI toolkit so that you can do everything you can to prevent people from creating something that's really going to cause an existential
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, many more people will be trained in algorithms that can make their own decisions about who to go after. It would be nice to have the AI revolutionize the way we think about life.
#
# This isn't the kind of world where the people whose lives are affected by machines will be able to buy their own homes, or buy their own cars. But it's far from over. A growing number of people who believe a technology that allows for people to
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, this is one of the reasons why we need it – and many more reasons to become it!
#
# This guide will help you better understand AI, its implications for business, and our current state of the field. If you want to learn more, you can check out the first few hours of our guide:
#
# 1. Why do we need AI?
#
# As AI has become widely available, the cost of developing a system has become high.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it's time to change the rules on what computers can learn to be useful.
#
# For example, robots in some areas are able to "learn" something about you (and their behavior) from a source code and be useful. But their behavior is only effective if the source code is good and the machine can learn it from the source code. In the same way a computer can learn a language that can be used in a real world in any way
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Temperature Sampling

# %% [markdown]
# ![Google Drive Image](https://drive.google.com/uc?export=view&id=142UUXEJh32oKF90iBYN5jZvVE42pUqJI)

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
temperature_outputs = model.generate(
    input_ids,
    max_length=100,
    do_sample=True,
    temperature=0.7,  # Control randomness with the temperature parameter
    num_return_sequences=5  # How many outputs to generate
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(temperature_outputs):
    print(f"Output {i+1}:\n{tokenizer.decode(output, skip_special_tokens=True)}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, it's easy to see the potential for it to become a problem.
#
# "It's very important to understand the potential for AI to change, to develop," says Kishore Kumar, president of the AI Foundation. "The AI Foundation is making a conscious effort to make sure that people come out and say, 'We should all be working with this AI.' We have no idea how it will come to be.
#
# "We have to
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, it's no wonder that there are so many new inventions.
#
# In 2015, Google gave us a glimpse of how the AI revolution could be harnessed. In an repressive and totalitarian world, it's easy to imagine that no one would be doing anything about it, and there are few people who would do anything about it. As Google is developing its autonomous cars, many will be working on their own autonomous cars.
#
# A year after the invention
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, artificial intelligence technology will play an increasingly important role in our daily lives. But what about the role of AI in the workplace? A new survey by the Pew Research Center finds that nearly half of Americans believe that artificial intelligence is a threat to their jobs and their well-being.
#
# A survey of 1,000 U.S. adults conducted in May by the Pew Research Center found that less than half (49%) believe that AI will cause jobs to
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, we want to make it so.
#
# That's why we're putting together a team of developers working on a first-of-its-kind AI project. Our goal is to help you create a world where you can create AI with the power of your imagination. By using AI to build AI, you'll create AI that can understand and solve problems as they arise.
#
# In a world where AI has become ubiquitous, we want to make it
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it's hard for any company to be the only company that's using it to better its products and services. But in a world where artificial intelligence comes before humans, it's hard to think of things that are better than what's available right now.
#
# Why not take a look at some of the other AI companies that have been using this technology, and see which ones are doing better:
#
# Github
#
# Github has a rather unique
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
temperature_outputs = model.generate(
    input_ids,
    max_length=100,
    do_sample=True,
    temperature=0.7,  # Control randomness with the temperature parameter
    num_return_sequences=5,  # How many outputs to generate
    eos_token_id=tokenizer.eos_token_id,  # Stop generation at EOS token
    pad_token_id=tokenizer.pad_token_id   # If the output is shorter than max_length, it'll be padded
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(temperature_outputs):
    generated_text = tokenizer.decode(output, skip_special_tokens=True).strip()
    print(f"Output {i+1}:\n{generated_text}\n")
    print("-" * 140, "\n")
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, it is difficult to be confident that we will ever be able to build a fully autonomous car. However, even if we did, it would still take a considerable amount of time and effort to create one. And the fact that AI is now so commonplace doesn't mean that it will be replaced by a more powerful robot.
#
# This is why I believe that the future of autonomous vehicles will have to come from a technology that is already being used for real
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, it is difficult for the company to ignore the fact that AI is just one of many ways that AI processes human behavior.
#
# With such a large number of applications, it becomes difficult to see how the company is going to avoid the subject matter of this post. But for now, let's look at the main points.
#
# What is AI?
#
# AI is a social and technological system in which computers (and other computers) are able to
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, it seems like the entire future of this computer may be in jeopardy. And if you think of it, it's a pretty safe bet that our future will be pretty bad.
#
# The Internet of Things (IoT) is the most advanced computer ever built, and is slated to take the place of the world's most advanced home, which is expected to come in at 1 billion by 2015. But the IoT has some troubling issues.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, I'd like to believe that the first steps in the process of using AI will be to build a human-focused network."
#
# The concept of AI was first introduced in 1998 by the physicist Richard Feynman, who described it as "the next step in the evolution of consciousness."
#
# "We are very much in the early stages of that process," says Professor Gautam Gambhir, who led the work. "But we are
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it's important to remember that it's not just the AI that's driving the machine through the world. There's a more sinister and troubling aspect to the AI, and that's that it's not just the AI, but also the systems that it's interacting with that make the world feel 'alive.'
#
# You've mentioned in your TED talk that you were really impressed by the way that people are using social media as a tool to express themselves
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
temperature_outputs = model.generate(
    input_ids,
    max_length=200,
    do_sample=True,
    temperature=0.7,
    num_return_sequences=5
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(temperature_outputs):
    generated_text = tokenizer.decode(output, skip_special_tokens=True).strip()
    # Check if EOS token exists in the output and trim up to that
    if '<|endoftext|>' in generated_text:
        generated_text = generated_text.split('<|endoftext|>')[0].strip()
    else:
        # Alternatively, trim up to the last period for coherence
        generated_text = '. '.join(generated_text.split('. ')[:-1]) + '.'
    print(f"Output {i+1}:\n{generated_text}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous,posal might be less of a stretch. A recent survey of 3,000 companies by the British Computer Corporation found that AI could easily outperform the human-computer ratio of 1; this is more than double the ratio of 1 (and a lot more than the ratio of 1 to 3). And while some AI researchers, like Ray Kurzweil, say that AI could be used to solve problems in a way that is similar to human-computer interactions, the project is looking further into the future.
#
# A new paper published recently in the journal Proceedings of the National Academy of Sciences suggests that a new kind of AI might be possible. It's called The Road to AI. It's a much-anticipated piece of research that was first conceived as part of a three-year project by Karp Karpov, an AI researcher at the University of Leeds, UK, and now at the University of Nottingham in the United Kingdom.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, we've seen it evolve from a concept that was not even mentioned before. It's now something that's not only relevant for business, but also for science and engineering, where we can apply it.
#
# We're looking at this as a potential avenue for bringing AI to the world. So we're looking at having it in our hands, and we're looking at what the next step will be for it.
#
# How do you think the future of AI will be?
#
# AI is now ubiquitous. Some people say it's going to be ubiquitous for a long time, and that's a pretty big deal, but the number of people who are really interested in AI in the near future has been growing pretty steadily.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, human interaction has become something of an afterthought. It's all about making human interaction more human by doing things with less human-like behaviors, and that's something we've been doing with our own species for a long time.
#
# The problem is that it's not just that AI is doing things with less human-like behaviors. It's that human interaction is a pretty slow process. I don't think we've ever used that concept of human interaction to understand the context of our interactions with other species. I think we've just assumed that we're talking to a bunch of creatures with a little bit more human-like behavior. But we're not.
#
# The human interaction that we're talking about is the interaction between two people that's about to end. They're both being used to accomplish something. I think we've got to be open to that.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it's hard to go wrong with this strategy. It's a great way to build up an organization and make a case for the benefits of AI.
#
# 3. Build the case for a specific technology
#
# "The most important thing is to build the case for that technology and to have that case for that technology."
#
# If you have a company that's got some interesting technology in it, you can also build the case for it. You can build the case for it by building the case for an AI-driven, AI-powered business. But be careful, because AI is evolving. So don't just build the case forUsers.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, we're seeing new ways of learning about how the world is going. Many of us have never experienced human beings doing this, but there are ways to learn about what it's like to be human.
#
# What about AI's role in the world we live in?
#
# If we can learn that human beings are completely different from other beings, we can learn that humans are better scientists than other people, and that we can learn to love and care for one another. We can learn to love one another, and we can learn to love other people. So those are the challenges that we will face as we try to create the world we want to live in.
#
# The world we live in is a very different place than it was back when we were kids.
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Instantiate the model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
temperature_outputs = model.generate(
    input_ids,
    max_length=400,  # More generous max_length
    do_sample=True,
    temperature=0.7,
    num_return_sequences=5,
    eos_token_id=tokenizer.eos_token_id
)

# Post-process outputs: Trim after the last full stop before a desired length
def trim_output(text, desired_max_length=250):
    if len(text) <= desired_max_length:
        return text
    last_full_stop = text.rfind('.', 0, desired_max_length)
    if last_full_stop == -1:
        return text[:desired_max_length]  # Fallback: truncate at desired_max_length
    return text[:last_full_stop + 1]

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(temperature_outputs):
    full_output = tokenizer.decode(output, skip_special_tokens=True)
    trimmed_output = trim_output(full_output)
    print(f"Output {i+1}:\n{trimmed_output}\n")
    print("-" * 140, "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, it's important to remember that robots are not just about us; they are also about you.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, the potential of humans, robots, and AI-powered car- and-car-driving machines will continue to grow exponentially.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, it seems that many of us have become better at our job at it.
#
# Ahead of the release of the AI and robotics products, I asked a few researchers if there were any trends that are affecting the industry.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it is important to understand what it means to have a human being as a human being as opposed to a machine.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it is important to understand the underlying problem and how it can be addressed.
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Using Falcon 7B with Sampling Methods
#
# Here you can try out the Falcon 7B model with different variations of sampling methods. This should give you an idea how the output of your chosen model can vary based on the sampling strategy. Take a close look at the different outputs of the LLM. Also, examine how the following model outputs differ from each other. As mentioned in the book, the closer the temperature parameter is set to 1, the more "creative" the model will be.

# %%
# Model and tokenizer
model_name = "tiiuae/falcon-7b"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Define the input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
outputs = model.generate(
    input_ids,
    max_length=200,  # max_length to match the desired output
    do_sample=True,
    temperature=0.7,  # Control randomness with the temperature parameter
    top_k=10,
    num_return_sequences=5,  # How many outputs to generate
    eos_token_id=tokenizer.eos_token_id,  # Stop generation at EOS token
    pad_token_id=tokenizer.pad_token_id  # If the output is shorter than max_length, it'll be padded
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(outputs):
    generated_text = tokenizer.decode(output, skip_special_tokens=True).strip()
    print(f"Output {i+1}:\n{generated_text}\n")
    print("-" * 140, "\n")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# The current implementation of Falcon calls `torch.scaled_dot_product_attention` directly, this will be deprecated in the future in favor of the `BetterTransformer` API. Please install the latest optimum library with `pip install -U optimum` and call `model.to_bettertransformer()` to benefit from `torch.scaled_dot_product_attention` and future performance optimizations.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, we are witnessing the rise of an unprecedented wave of innovation. As AI is now available to everyone, we are seeing more and more businesses using AI to improve their operations, enhance their products and services, and increase their bottom lines.
# But, how is AI being used?
# In this article, we will look at some of the most common ways that AI is being used in the business world and how it is being applied to different industries.
# How is AI Being Used in the Business World?
# AI is a powerful tool that can be used to improve business operations, enhance products and services, and increase revenues. In fact, AI can be used in almost every industry and business function.
# Here are some of the most common ways that AI is being used in the business world:
# - Improving Customer Experience.
# - Streamlining Business Processes.
# - Optimizing Supply Chains.
# - Improving Sales and Marketing.
# - Improving Product and Service
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, the need for data-driven decisions and the ability to interpret data has become crucial for any organization or individual.
# The demand for data-driven insights and decision-making has increased in recent years. The need for data scientists has also risen. However, the supply of data scientists is far outstripped by the demand for them, leaving many organizations struggling to find talent.
# This demand for data-driven insights and decision-making has created an opportunity for data science. Data science is a discipline that uses data to make predictions and decisions. Data science is the use of data-driven insights and decision-making to improve business outcomes.
# Data science is the process of gathering, analyzing, and interpreting data to make predictions and decisions. It is the process of gathering, analyzing, and interpreting data to make predictions and decisions.
# Data science is a multidisciplinary field that uses data to make predictions and decisions. Data scientists use data to make predictions and decisions
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, we’re starting to see an explosion of companies trying to leverage AI to help with everything from customer service to marketing.
# But the reality is that many of these companies are still in their infancy.
# And while they may be able to provide valuable insights into how AI can help their customers, they’re not yet ready to fully leverage it.
# In this article, I’ll show you how you can leverage AI to drive growth for your business, and how you can get started with AI.
# Let’s get started.
# What is AI?
# AI is a type of machine learning that can be used to make decisions based on information about the world.
# For example, a self-driving car could use AI to detect a potential danger on the road, and automatically turn on the brakes.
# AI also has a lot of potential for business applications.
# For example, a company could use AI to help it make better decisions about
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it is no wonder that businesses and organizations are looking to incorporate this technology into their daily operations. In this blog post, we will explore some of the benefits of AI for business.
# Contents
# - 1 What are the benefits of AI in business?
# - 2 What are the advantages of AI in business?
# - 3 What are the disadvantages of AI in business?
# - 4 What is the future of AI in business?
# - 5 What are the advantages of AI in business and marketing?
# - 6 What are the disadvantages of AI in business?
# - 7 What are the benefits of AI in business and marketing?
# - 8 How is AI changing the workplace?
# - 9 What are the disadvantages of AI in business?
# - 10 What are the benefits of AI in business and finance?
# - 11 What are the disadvantages of AI in business and finance?
# - 12
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, where the Internet of Things is ubiquitous, where we can now do business from anywhere at anytime, the next frontier is the ability to do business with anyone, at any time, and on any device. This is a very powerful concept and one of the key drivers of the fourth industrial revolution, but it is also one that requires a new approach to security.
# As we move to more connected devices and more connected people, how do we protect our data? And how do we protect the systems that process that data?
# The answer is simple: we need to make sure that our data and our systems are protected in the same way that we protect our physical assets.
# This is the reason why we’ve created a suite of security solutions, including our flagship product, the Kaspersky Security Center.
# We have a deep understanding of the security landscape and have developed a number of solutions to help you secure your data and protect your systems.
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Model and tokenizer
model_name = "tiiuae/falcon-7b"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Define the input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output with temperature sampling
outputs = model.generate(
    input_ids,
    max_length=100,  # Adjusted max_length to match the desired output
    do_sample=True,
    temperature=0.1,  # Control randomness with the temperature parameter
    top_k=10,
    num_return_sequences=5,  # How many outputs to generate
    eos_token_id=tokenizer.eos_token_id,  # Stop generation at EOS token
    pad_token_id=tokenizer.pad_token_id  # If the output is shorter than max_length, it'll be padded
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(outputs):
    generated_text = tokenizer.decode(output, skip_special_tokens=True).strip()
    print(f"Output {i+1}:\n{generated_text}\n")
    print("-" * 140, "\n")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# The current implementation of Falcon calls `torch.scaled_dot_product_attention` directly, this will be deprecated in the future in favor of the `BetterTransformer` API. Please install the latest optimum library with `pip install -U optimum` and call `model.to_bettertransformer()` to benefit from `torch.scaled_dot_product_attention` and future performance optimizations.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, the need for human-like intelligence is more important than ever.
# The ability to understand and respond to human language is a key component of this.
# In this article, we’ll explore how to use AI to create a human-like AI that can understand and respond to human speech.
# We’ll also discuss how to use AI to create a human-like AI that can understand and respond to human emotions.
# What is AI?
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, it’s easy to forget that it’s still a relatively new technology.
# But as the technology continues to evolve, it’s becoming more and more important to understand how it works and how it can be used to improve our lives.
# Here are some of the most important things you need to know about AI.
# What is AI?
# AI is a technology that uses artificial intelligence to make decisions.
# It’s a technology that can
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, it’s easy to forget that it’s still a relatively new technology.
# But as AI continues to evolve, it’s becoming more and more important to understand how it works and what it can do.
# In this article, we’ll take a look at some of the most common misconceptions about AI and how they can be overcome.
# 1. AI is a new technology.
# AI is a relatively new technology, but it’s
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, it is important to understand the impact of AI on the future of work. AI is already being used in many industries, including healthcare, finance, and retail. It is also being used in the home, where it can help with tasks such as cooking and cleaning.
# The impact of AI on the future of work is still being debated. Some people believe that AI will make jobs obsolete, while others believe that it will create new jobs. It is important
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, it is important to understand the impact of AI on the future of work.
# The future of work is a topic that has been discussed for many years, but it is only recently that we are starting to see the impact of AI on the workforce.
# In this article, we will explore the impact of AI on the future of work and how it will affect the workforce.
# What is AI?
# Artificial intelligence (AI) is a branch
#
# --------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Instantiate the model and tokenizer
model_name = "tiiuae/falcon-7b"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Define an input prompt
prompt = "In a world where AI has become ubiquitous,"

# Encode the input prompt and prepare it for the model
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate text output
outputs = model.generate(
    input_ids,
    max_length=200,
    do_sample=True,
    temperature=0.7,
    num_return_sequences=5
)

# Print the resulting sentences
print("\033[1m" + "Output:\n" + 140 * '=' + "\033[0m")
for i, output in enumerate(outputs):
    generated_text = tokenizer.decode(output, skip_special_tokens=True).strip()
    # Check if the EOS token exists in the output and trim up to that
    eos_token = tokenizer.eos_token
    if eos_token and eos_token in generated_text:
        generated_text = generated_text.split(eos_token)[0].strip()
    else:
        # Alternatively, trim up to the last period for coherence
        generated_text = '. '.join(generated_text.split('. ')[:-1]) + '.'
    print(f"Output {i+1}:\n{generated_text}\n")
    print("-" * 140, "\n")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# The current implementation of Falcon calls `torch.scaled_dot_product_attention` directly, this will be deprecated in the future in favor of the `BetterTransformer` API. Please install the latest optimum library with `pip install -U optimum` and call `model.to_bettertransformer()` to benefit from `torch.scaled_dot_product_attention` and future performance optimizations.
# Output:
# ============================================================================================================================================
# Output 1:
# In a world where AI has become ubiquitous, the need for high-quality data is paramount. The data has to be as accurate as possible to ensure that the algorithms are performing at their best.
# How many times have you seen a bot or AI-powered app give you a “no results found” message when you’ve asked for something that should be in their database?
# It happens more often than you’d think, and it’s a great example of how data quality is essential for the success of any machine learning project.
# If you want your data to be useful, it has to be accurate. If it’s not accurate, it could result in some serious problems for your business.
# For example, if your algorithm is trained on inaccurate data, it will only be as accurate as the training data you provided.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 2:
# In a world where AI has become ubiquitous, how do we ensure that AI is fair? In this talk, we will explore how data scientists and engineers can work together to ensure that AI is fair. We will also learn from case studies of the AI systems that have gone awry, and how they can be fixed, to understand what are the ethical principles for designing AI that is fair, and how engineers and data scientists can apply those principles in their work.
# Speaker:
# Nidhi Sharma was the Data Scientist in Residence at Data + Society at NYU. She holds an MSc in Machine Learning from Imperial College London, and is presently pursuing a PhD in Computer Science from NYU. She is the co-author of the book “The Ethics of Artificial Intelligence” (2019), and has published more than 20 peer-reviewed papers in top conferences such as NeurIPS and ICML.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 3:
# In a world where AI has become ubiquitous, it is important to remember that AI is not a panacea.
# That’s according to a University of Adelaide scholar, who says while AI has great potential, it is often misused and can be an enabler of bad behaviour.
# “AI is not a moral agent,” said Dr David McNeill, a lecturer in data-driven decision making at the University’s School of Computer Science.
# “It is a tool, and we should be aware of its limitations and ethical issues.”
# Dr McNeill was one of the lead authors of a new research paper which found that AI was a “potential risk” to society, given its current capabilities and limitations.
# He said the study showed that the technology was not yet ready to replace human beings in the workforce.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 4:
# In a world where AI has become ubiquitous, machine learning is now an essential tool to help us understand and interpret the data we’re collecting every day. Machine learning is a branch of artificial intelligence that, like human intelligence, uses algorithms to help computers learn and adapt to new information. Machine learning has been around for a long time, but it’s only recently that we’ve begun to see a shift in the way we use it.
# What is Machine Learning?
# Machine learning is a type of artificial intelligence (AI) that allows computers to learn from data and make predictions without being explicitly programmed. Machine learning is becoming more important in business, healthcare, and science, as it can help machines make decisions more quickly and accurately than humans. Machine learning has become an essential tool for scientists, doctors, and business professionals.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Output 5:
# In a world where AI has become ubiquitous, there is a growing concern for the ethics of AI. As the world moves towards AI, the focus on ethics will become more important. The future of AI is uncertain, but one thing is for sure: AI will continue to change the way we live.
# Artificial Intelligence is a technology that has the potential to change the lives of millions of people. It has already been used in many fields, such as robotics, medicine, and defense. The AI market is expected to be worth $47 billion by 2020.
# AI is a technology that has the potential to Applying AI to the healthcare sector will help to improve patient care and make healthcare more affordable for all. It can also help to reduce the amount of time and resources spent on administrative tasks, allowing more time for patient care.
# Artificial Intelligence is the study of how to make computers behave like humans. wypadki.
#
# --------------------------------------------------------------------------------------------------------------------------------------------
